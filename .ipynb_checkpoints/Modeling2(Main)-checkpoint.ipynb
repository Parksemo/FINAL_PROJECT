# %%
import pickle
import numpy as np
import pandas as pd
import os
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
with open('df_scaled2.pickle','rb') as f:
    df_scaled = pickle.load(f)
with open('sector.pickle','rb') as f:
    sector = pickle.load(f)

# %%
from datetime import date,datetime
today = date.today()
today = today.isoformat()
today = today.replace('-','')
yesterday = int(today)-1
yesterday = str(yesterday)
print(yesterday, type(yesterday))
set_d = yesterday
# Out:
# 20220719 <class 'str'>

# %%
from sklearn.model_selection import train_test_split
X_train_dic = {}
X_test_dic={}
y_train_dic = {}
y_test_dic = {}
#모델이 각 업종마다 존재한다. 18개
for sector_name, df in df_scaled.items():
    # 단 셔플 없이 분할
    X_train, X_test, y_train, y_test = train_test_split(df.drop('종가', 1), df['종가'], test_size=0.2, random_state=0, shuffle=False)
    X_train_dic[sector_name] = X_train
    X_test_dic[sector_name] = X_test
    y_train_dic[sector_name] = y_train
    y_test_dic[sector_name] = y_test

# %%
X_train_dic['Food'].shape, y_train_dic['Food'].shape
# Out:
# ((2400, 4), (2400,))

# %%
X_test_dic['Food'].shape, y_test_dic['Food'].shape
# Out:
# ((601, 4), (601,))

# %% [markdown]
# # 윈도우 데이터 셋 생성

# %%
# 윈도우 데이터셋 생성 함수
def windowed_dataset(X, y, X_size, y_size, X_shift, y_shift, X_stride, y_stride, batch_size):
    
    # numpy array x(input)를 Dataset으로 변환
    ds_x = tf.data.Dataset.from_tensor_slices(X)
    
    #윈도우셋 구성
    ds_x = ds_x.window(size=X_size,stride=X_stride, shift=X_shift, drop_remainder=True)
    #한 차원 줄야사 반환
    ds_x = ds_x.flat_map(lambda x: x.batch(X_size))
    
    ds_y = tf.data.Dataset.from_tensor_slices(y)
    ds_y = ds_y.window(size=y_size, stride=y_stride, shift=y_shift, drop_remainder=True)
    ds_y = ds_y.flat_map(lambda y: y.batch(y_size))
    
    #같은 인덱스에 있는 애들 끼리 묶기
    ds = tf.data.Dataset.zip((ds_x, ds_y))
    
    return ds.batch(batch_size).prefetch(1)

# %% [markdown]
# ## 파라미터 지정

# %%
#윈도우 사이즈
WINDOW_SIZE = 10
# X에 대한 윈도우 함수 설정값
X_size = WINDOW_SIZE
X_shift = 10
X_stride = 1
# y에 대한 윈도우 함수 설정값
y_size = 1
y_shift = WINDOW_SIZE
y_stride = 1

batch_size = 1

# %%
tf_dataset_train_dic={}
for sector_name, X_train in X_train_dic.items():
    y_train = y_train_dic[sector_name]
    tf_dataset_train_dic[sector_name] = windowed_dataset(X_train,y_train[WINDOW_SIZE:], X_size, y_size,
                                X_shift, y_shift, X_stride, y_stride, batch_size)

tf_dataset_test_dic = {}
for sector_name, X_test in X_test_dic.items():
    y_test = y_test_dic[sector_name]
    tf_dataset_test_dic[sector_name] = windowed_dataset(X_test,y_test[WINDOW_SIZE:], X_size, y_size,
                                X_shift, y_shift, X_stride, y_stride, batch_size)

    # 데이터 shape, 미리보기로 체크
for x, y in tf_dataset_train_dic['Food'].take(3):
    print('X:', x.shape)
    print(x)
    print()
    print('Y:', y.shape)
    print(y)
    print('-'*100)
# Out:
# X: (1, 10, 4)
# tf.Tensor(
# [[[0.02383223 0.06842555 0.05423167 0.1034161 ]
#   [0.01920244 0.06794263 0.05187154 0.1027709 ]
#   [0.03917412 0.06308562 0.04437396 0.07655971]
#   [0.04225737 0.05670212 0.0438025  0.08195749]
#   [0.06395201 0.05739598 0.04494543 0.08973443]
#   [0.03599058 0.06502842 0.04208812 0.095426  ]
#   [0.02599399 0.07682402 0.05366021 0.10291491]
#   [0.02091734 0.06884187 0.0487285  0.10399217]
#   [0.0379419  0.0818198  0.05966055 0.10730457]
#   [0.01763888 0.07952729 0.05323161 0.10298404]]], shape=(1, 10, 4), dtype=float64)
#
# Y: (1, 1)
# tf.Tensor([[0.07962388]], shape=(1, 1), dtype=float64)
# ----------------------------------------------------------------------------------------------------
# X: (1, 10, 4)
# tf.Tensor(
# [[[0.01986691 0.05850615 0.03965941 0.09629011]
#   [0.01642815 0.06356854 0.03887079 0.09088657]
#   [0.01617651 0.05857276 0.03865935 0.09304683]
#   [0.02629668 0.06148697 0.04708841 0.09773028]
#   [0.03018051 0.06891403 0.05023144 0.10104269]
#   [0.02009616 0.07196701 0.05437454 0.10910767]
#   [0.00832109 0.07751787 0.05337448 0.11112391]
#   [0.01355087 0.07286625 0.04929996 0.10651535]
#   [0.02565281 0.0709956  0.04808846 0.10478714]
#   [0.02924559 0.07474244 0.05001429 0.10651535]]], shape=(1, 10, 4), dtype=float64)
#
# Y: (1, 1)
# tf.Tensor([[0.10079308]], shape=(1, 1), dtype=float64)
# ----------------------------------------------------------------------------------------------------
# X: (1, 10, 4)
# tf.Tensor(
# [[[0.02741338 0.07335472 0.05872907 0.11205715]
#   [0.01634218 0.076058   0.05437454 0.10946483]
#   [0.01209029 0.07613016 0.05430025 0.11464946]
#   [0.00846168 0.07904436 0.05694611 0.1124892 ]
#   [0.02372746 0.08764821 0.06172924 0.11501239]
#   [0.01616129 0.08834207 0.06423224 0.12322138]
#   [0.0147616  0.09049025 0.06994685 0.12638977]
#   [0.01820753 0.08515032 0.06515801 0.1233654 ]
#   [0.01256044 0.08084839 0.06223213 0.1142923 ]
#   [0.0169968  0.08792575 0.06094634 0.11407339]]], shape=(1, 10, 4), dtype=float64)
#
# Y: (1, 1)
# tf.Tensor([[0.11068865]], shape=(1, 1), dtype=float64)
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 모델

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, Lambda
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
model_dic ={}
for sector_name in sector.keys():
    model_dic[sector_name] = Sequential([
        # 1차원 feature map 생성
        Conv1D(filters=32, kernel_size=5,
               padding="causal",
               activation="relu",
               #feature의 개수 3개
               input_shape=[WINDOW_SIZE, 4]),
        # LSTM
        LSTM(16, activation='tanh'),
        Dense(16, activation="relu"),
        Dense(1),
    ])

# %%
# Sequence 학습에 비교적 좋은 퍼포먼스를 내는 Huber()를 사용합니다.
loss = Huber()
optimizer = Adam(0.0005)
for sector_model in model_dic.values():
    sector_model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])

# %%
# earlystopping은 10번 epoch통안 val_loss 개선이 없다면 학습을 멈춥니다.
earlystopping = EarlyStopping(monitor='val_loss', patience=10)

# %%
# val_loss 기준 체크포인터도 생성합니다.
filename_dic={}
for sector_name in sector.keys():
    filename_dic[sector_name] = os.path.join('tmp2', sector_name+'ckeckpointer.ckpt')

# %%
#체크포인트를 저장    
mc_dic = {}
for sector_name in filename_dic:
    mc_dic[sector_name] = ModelCheckpoint(filename_dic[sector_name], 
                         save_weights_only=True, 
                         save_best_only=True, 
                         monitor='val_loss', 
                         verbose=1)

# %%
history_dic={}
# 학습+저장
for sector_name, train_data in tf_dataset_train_dic.items():
    test_data = tf_dataset_test_dic[sector_name]
    history = model_dic[sector_name].fit(train_data, 
                        validation_data=(test_data), 
                        epochs=50, 
                        callbacks=[mc_dic[sector_name], earlystopping])
    history_dic[sector_name] = history
with open('history_dic.pickle', 'wb') as f:
    pickle.dump(history_dic,f)
# Out:
# Epoch 1/50
# 239/239 [==============================] - 3s 7ms/step - loss: 0.0052 - mse: 0.0105 - val_loss: 0.0108 - val_mse: 0.0216
#
# Epoch 00001: val_loss improved from inf to 0.01078, saving model to tmp2\Foodckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0017 - mse: 0.0034 - val_loss: 0.0033 - val_mse: 0.0067
#
# Epoch 00002: val_loss improved from 0.01078 to 0.00333, saving model to tmp2\Foodckeckpointer.ckpt
# Epoch 3/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0011 - mse: 0.0023 - val_loss: 0.0021 - val_mse: 0.0042
#
# Epoch 00003: val_loss improved from 0.00333 to 0.00210, saving model to tmp2\Foodckeckpointer.ckpt
# Epoch 4/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0011 - mse: 0.0021 - val_loss: 0.0028 - val_mse: 0.0056
#
# Epoch 00004: val_loss did not improve from 0.00210
# Epoch 5/50
# 239/239 [==============================] - 1s 5ms/step - loss: 8.9503e-04 - mse: 0.0018 - val_loss: 0.0014 - val_mse: 0.0028
#
# Epoch 00005: val_loss improved from 0.00210 to 0.00141, saving model to tmp2\Foodckeckpointer.ckpt
# Epoch 6/50
# 239/239 [==============================] - 1s 5ms/step - loss: 8.6724e-04 - mse: 0.0017 - val_loss: 0.0014 - val_mse: 0.0029
#
# Epoch 00006: val_loss did not improve from 0.00141
# Epoch 7/50
# 239/239 [==============================] - 1s 5ms/step - loss: 8.2800e-04 - mse: 0.0017 - val_loss: 0.0012 - val_mse: 0.0024
#
# Epoch 00007: val_loss improved from 0.00141 to 0.00121, saving model to tmp2\Foodckeckpointer.ckpt
# Epoch 8/50
# 239/239 [==============================] - 1s 5ms/step - loss: 7.9499e-04 - mse: 0.0016 - val_loss: 0.0010 - val_mse: 0.0020
#
# Epoch 00008: val_loss improved from 0.00121 to 0.00101, saving model to tmp2\Foodckeckpointer.ckpt
# Epoch 9/50
# 239/239 [==============================] - 1s 6ms/step - loss: 7.3356e-04 - mse: 0.0015 - val_loss: 8.0954e-04 - val_mse: 0.0016
#
# Epoch 00009: val_loss improved from 0.00101 to 0.00081, saving model to tmp2\Foodckeckpointer.ckpt
# Epoch 10/50
# 239/239 [==============================] - 1s 5ms/step - loss: 7.3686e-04 - mse: 0.0015 - val_loss: 9.8062e-04 - val_mse: 0.0020
#
# Epoch 00010: val_loss did not improve from 0.00081
# Epoch 11/50
# 239/239 [==============================] - 1s 5ms/step - loss: 7.5312e-04 - mse: 0.0015 - val_loss: 7.1502e-04 - val_mse: 0.0014
#
# Epoch 00011: val_loss improved from 0.00081 to 0.00072, saving model to tmp2\Foodckeckpointer.ckpt
# Epoch 12/50
# 239/239 [==============================] - 1s 5ms/step - loss: 7.2995e-04 - mse: 0.0015 - val_loss: 6.8708e-04 - val_mse: 0.0014
#
# Epoch 00012: val_loss improved from 0.00072 to 0.00069, saving model to tmp2\Foodckeckpointer.ckpt
# Epoch 13/50
# 239/239 [==============================] - 1s 5ms/step - loss: 7.0162e-04 - mse: 0.0014 - val_loss: 6.8688e-04 - val_mse: 0.0014
#
# Epoch 00013: val_loss improved from 0.00069 to 0.00069, saving model to tmp2\Foodckeckpointer.ckpt
# Epoch 14/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.5358e-04 - mse: 0.0013 - val_loss: 0.0024 - val_mse: 0.0049
#
# Epoch 00014: val_loss did not improve from 0.00069
# Epoch 15/50
# 239/239 [==============================] - 1s 5ms/step - loss: 8.1907e-04 - mse: 0.0016 - val_loss: 0.0013 - val_mse: 0.0026
#
# Epoch 00015: val_loss did not improve from 0.00069
# Epoch 16/50
# 239/239 [==============================] - 1s 5ms/step - loss: 7.7786e-04 - mse: 0.0016 - val_loss: 6.5813e-04 - val_mse: 0.0013
#
# Epoch 00016: val_loss improved from 0.00069 to 0.00066, saving model to tmp2\Foodckeckpointer.ckpt
# Epoch 17/50
# 239/239 [==============================] - 1s 5ms/step - loss: 7.5318e-04 - mse: 0.0015 - val_loss: 6.6925e-04 - val_mse: 0.0013
#
# Epoch 00017: val_loss did not improve from 0.00066
# Epoch 18/50
# 239/239 [==============================] - 1s 5ms/step - loss: 7.1283e-04 - mse: 0.0014 - val_loss: 5.8236e-04 - val_mse: 0.0012
#
# Epoch 00018: val_loss improved from 0.00066 to 0.00058, saving model to tmp2\Foodckeckpointer.ckpt
# Epoch 19/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.8907e-04 - mse: 0.0014 - val_loss: 7.1471e-04 - val_mse: 0.0014
#
# Epoch 00019: val_loss did not improve from 0.00058
# Epoch 20/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.9387e-04 - mse: 0.0014 - val_loss: 5.4771e-04 - val_mse: 0.0011
#
# Epoch 00020: val_loss improved from 0.00058 to 0.00055, saving model to tmp2\Foodckeckpointer.ckpt
# Epoch 21/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.8763e-04 - mse: 0.0014 - val_loss: 6.5431e-04 - val_mse: 0.0013
#
# Epoch 00021: val_loss did not improve from 0.00055
# Epoch 22/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.8862e-04 - mse: 0.0014 - val_loss: 5.0767e-04 - val_mse: 0.0010
#
# Epoch 00022: val_loss improved from 0.00055 to 0.00051, saving model to tmp2\Foodckeckpointer.ckpt
# Epoch 23/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.7433e-04 - mse: 0.0013 - val_loss: 5.0643e-04 - val_mse: 0.0010
#
# Epoch 00023: val_loss improved from 0.00051 to 0.00051, saving model to tmp2\Foodckeckpointer.ckpt
# Epoch 24/50
# 239/239 [==============================] - 1s 6ms/step - loss: 6.6744e-04 - mse: 0.0013 - val_loss: 5.9944e-04 - val_mse: 0.0012
#
# Epoch 00024: val_loss did not improve from 0.00051
# Epoch 25/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.6090e-04 - mse: 0.0013 - val_loss: 4.7325e-04 - val_mse: 9.4649e-04
#
# Epoch 00025: val_loss improved from 0.00051 to 0.00047, saving model to tmp2\Foodckeckpointer.ckpt
# Epoch 26/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.4655e-04 - mse: 0.0013 - val_loss: 5.7037e-04 - val_mse: 0.0011
#
# Epoch 00026: val_loss did not improve from 0.00047
# Epoch 27/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.4319e-04 - mse: 0.0013 - val_loss: 4.6789e-04 - val_mse: 9.3579e-04
#
# Epoch 00027: val_loss improved from 0.00047 to 0.00047, saving model to tmp2\Foodckeckpointer.ckpt
# Epoch 28/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.2644e-04 - mse: 0.0013 - val_loss: 5.4728e-04 - val_mse: 0.0011
#
# Epoch 00028: val_loss did not improve from 0.00047
# Epoch 29/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.9684e-04 - mse: 0.0012 - val_loss: 6.1520e-04 - val_mse: 0.0012
#
# Epoch 00029: val_loss did not improve from 0.00047
# Epoch 30/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.5096e-04 - mse: 0.0013 - val_loss: 5.4107e-04 - val_mse: 0.0011
#
# Epoch 00030: val_loss did not improve from 0.00047
# Epoch 31/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.3853e-04 - mse: 0.0013 - val_loss: 5.6821e-04 - val_mse: 0.0011
#
# Epoch 00031: val_loss did not improve from 0.00047
# Epoch 32/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.1270e-04 - mse: 0.0012 - val_loss: 4.9843e-04 - val_mse: 9.9685e-04
#
# Epoch 00032: val_loss did not improve from 0.00047
# Epoch 33/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.9137e-04 - mse: 0.0012 - val_loss: 4.6942e-04 - val_mse: 9.3883e-04
#
# Epoch 00033: val_loss did not improve from 0.00047
# Epoch 34/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.7770e-04 - mse: 0.0012 - val_loss: 4.5779e-04 - val_mse: 9.1558e-04
#
# Epoch 00034: val_loss improved from 0.00047 to 0.00046, saving model to tmp2\Foodckeckpointer.ckpt
# Epoch 35/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.6588e-04 - mse: 0.0011 - val_loss: 4.6269e-04 - val_mse: 9.2538e-04
#
# Epoch 00035: val_loss did not improve from 0.00046
# Epoch 36/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.4716e-04 - mse: 0.0011 - val_loss: 4.4726e-04 - val_mse: 8.9451e-04
#
# Epoch 00036: val_loss improved from 0.00046 to 0.00045, saving model to tmp2\Foodckeckpointer.ckpt
# Epoch 37/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.3425e-04 - mse: 0.0011 - val_loss: 3.9533e-04 - val_mse: 7.9066e-04
#
# Epoch 00037: val_loss improved from 0.00045 to 0.00040, saving model to tmp2\Foodckeckpointer.ckpt
# Epoch 38/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.1877e-04 - mse: 0.0010 - val_loss: 4.5360e-04 - val_mse: 9.0720e-04
# Epoch 00038: val_loss did not improve from 0.00040
# Epoch 39/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.0210e-04 - mse: 0.0010 - val_loss: 4.6453e-04 - val_mse: 9.2907e-04
#
# Epoch 00039: val_loss did not improve from 0.00040
# Epoch 40/50
# 239/239 [==============================] - 1s 5ms/step - loss: 4.9159e-04 - mse: 9.8318e-04 - val_loss: 4.5175e-04 - val_mse: 9.0351e-04
#
# Epoch 00040: val_loss did not improve from 0.00040
# Epoch 41/50
# 239/239 [==============================] - 1s 5ms/step - loss: 4.7901e-04 - mse: 9.5802e-04 - val_loss: 4.6052e-04 - val_mse: 9.2105e-04
#
# Epoch 00041: val_loss did not improve from 0.00040
# Epoch 42/50
# 239/239 [==============================] - 1s 5ms/step - loss: 4.7058e-04 - mse: 9.4115e-04 - val_loss: 4.2599e-04 - val_mse: 8.5199e-04
#
# Epoch 00042: val_loss did not improve from 0.00040
# Epoch 43/50
# 239/239 [==============================] - 1s 5ms/step - loss: 4.6225e-04 - mse: 9.2450e-04 - val_loss: 4.2037e-04 - val_mse: 8.4075e-04
#
# Epoch 00043: val_loss did not improve from 0.00040
# Epoch 44/50
# 239/239 [==============================] - 1s 5ms/step - loss: 4.5926e-04 - mse: 9.1851e-04 - val_loss: 4.2298e-04 - val_mse: 8.4596e-04
#
# Epoch 00044: val_loss did not improve from 0.00040
# Epoch 45/50
# 239/239 [==============================] - 1s 5ms/step - loss: 4.4596e-04 - mse: 8.9191e-04 - val_loss: 4.0903e-04 - val_mse: 8.1807e-04
#
# Epoch 00045: val_loss did not improve from 0.00040
# Epoch 46/50
# 239/239 [==============================] - 1s 5ms/step - loss: 4.4460e-04 - mse: 8.8920e-04 - val_loss: 4.0725e-04 - val_mse: 8.1451e-04
#
# Epoch 00046: val_loss did not improve from 0.00040
# Epoch 47/50
# 239/239 [==============================] - 1s 5ms/step - loss: 4.3148e-04 - mse: 8.6296e-04 - val_loss: 3.9546e-04 - val_mse: 7.9092e-04
#
# Epoch 00047: val_loss did not improve from 0.00040
# Epoch 1/50
# 239/239 [==============================] - 3s 6ms/step - loss: 5.6399e-04 - mse: 0.0011 - val_loss: 0.0753 - val_mse: 0.1506
#
# Epoch 00001: val_loss improved from inf to 0.07532, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 5ms/step - loss: 8.6829e-04 - mse: 0.0017 - val_loss: 0.0588 - val_mse: 0.1175
#
# Epoch 00002: val_loss improved from 0.07532 to 0.05876, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 3/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0010 - mse: 0.0020 - val_loss: 0.0530 - val_mse: 0.1060
#
# Epoch 00003: val_loss improved from 0.05876 to 0.05298, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 4/50
# 239/239 [==============================] - 1s 5ms/step - loss: 7.8860e-04 - mse: 0.0016 - val_loss: 0.0510 - val_mse: 0.1019
#
# Epoch 00004: val_loss improved from 0.05298 to 0.05096, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 5/50
# 239/239 [==============================] - 1s 6ms/step - loss: 6.3179e-04 - mse: 0.0013 - val_loss: 0.0491 - val_mse: 0.0981
#
# Epoch 00005: val_loss improved from 0.05096 to 0.04906, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 6/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.2884e-04 - mse: 0.0011 - val_loss: 0.0478 - val_mse: 0.0955
#
# Epoch 00006: val_loss improved from 0.04906 to 0.04775, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 7/50
# 239/239 [==============================] - 1s 6ms/step - loss: 4.7887e-04 - mse: 9.5774e-04 - val_loss: 0.0463 - val_mse: 0.0925
#
# Epoch 00007: val_loss improved from 0.04775 to 0.04627, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 8/50
# 239/239 [==============================] - 1s 5ms/step - loss: 4.4749e-04 - mse: 8.9499e-04 - val_loss: 0.0450 - val_mse: 0.0899
#
# Epoch 00008: val_loss improved from 0.04627 to 0.04496, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 9/50
# 239/239 [==============================] - 1s 6ms/step - loss: 4.2814e-04 - mse: 8.5628e-04 - val_loss: 0.0439 - val_mse: 0.0879
#
# Epoch 00009: val_loss improved from 0.04496 to 0.04393, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 10/50
# 239/239 [==============================] - 1s 5ms/step - loss: 4.0388e-04 - mse: 8.0775e-04 - val_loss: 0.0419 - val_mse: 0.0838
#
# Epoch 00010: val_loss improved from 0.04393 to 0.04192, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 11/50
# 239/239 [==============================] - 1s 5ms/step - loss: 3.8118e-04 - mse: 7.6237e-04 - val_loss: 0.0407 - val_mse: 0.0814
#
# Epoch 00011: val_loss improved from 0.04192 to 0.04069, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 12/50
# 239/239 [==============================] - 1s 5ms/step - loss: 3.6367e-04 - mse: 7.2734e-04 - val_loss: 0.0397 - val_mse: 0.0794
#
# Epoch 00012: val_loss improved from 0.04069 to 0.03968, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 13/50
# 239/239 [==============================] - 1s 5ms/step - loss: 3.4849e-04 - mse: 6.9698e-04 - val_loss: 0.0388 - val_mse: 0.0776
#
# Epoch 00013: val_loss improved from 0.03968 to 0.03879, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 14/50
# 239/239 [==============================] - 1s 5ms/step - loss: 3.3435e-04 - mse: 6.6870e-04 - val_loss: 0.0379 - val_mse: 0.0759
#
# Epoch 00014: val_loss improved from 0.03879 to 0.03794, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 15/50
# 239/239 [==============================] - 1s 6ms/step - loss: 3.2084e-04 - mse: 6.4167e-04 - val_loss: 0.0373 - val_mse: 0.0745
#
# Epoch 00015: val_loss improved from 0.03794 to 0.03726, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 16/50
# 239/239 [==============================] - 1s 5ms/step - loss: 3.0943e-04 - mse: 6.1886e-04 - val_loss: 0.0366 - val_mse: 0.0732
#
# Epoch 00016: val_loss improved from 0.03726 to 0.03659, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 17/50
# 239/239 [==============================] - 1s 6ms/step - loss: 2.9889e-04 - mse: 5.9778e-04 - val_loss: 0.0360 - val_mse: 0.0721
#
# Epoch 00017: val_loss improved from 0.03659 to 0.03603, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 18/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.8966e-04 - mse: 5.7931e-04 - val_loss: 0.0356 - val_mse: 0.0711
#
# Epoch 00018: val_loss improved from 0.03603 to 0.03557, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 19/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.8188e-04 - mse: 5.6377e-04 - val_loss: 0.0351 - val_mse: 0.0702
#
# Epoch 00019: val_loss improved from 0.03557 to 0.03509, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 20/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.7332e-04 - mse: 5.4663e-04 - val_loss: 0.0347 - val_mse: 0.0695
#
# Epoch 00020: val_loss improved from 0.03509 to 0.03474, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 21/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.6964e-04 - mse: 5.3927e-04 - val_loss: 0.0344 - val_mse: 0.0687
#
# Epoch 00021: val_loss improved from 0.03474 to 0.03436, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 22/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.6248e-04 - mse: 5.2497e-04 - val_loss: 0.0340 - val_mse: 0.0681
#
# Epoch 00022: val_loss improved from 0.03436 to 0.03405, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 23/50
# 239/239 [==============================] - 1s 6ms/step - loss: 2.5853e-04 - mse: 5.1707e-04 - val_loss: 0.0337 - val_mse: 0.0674
#
# Epoch 00023: val_loss improved from 0.03405 to 0.03372, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 24/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.5314e-04 - mse: 5.0627e-04 - val_loss: 0.0334 - val_mse: 0.0669
#
# Epoch 00024: val_loss improved from 0.03372 to 0.03344, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 25/50
# 239/239 [==============================] - 1s 6ms/step - loss: 2.4891e-04 - mse: 4.9781e-04 - val_loss: 0.0333 - val_mse: 0.0667
#
# Epoch 00025: val_loss improved from 0.03344 to 0.03334, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 26/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.4388e-04 - mse: 4.8777e-04 - val_loss: 0.0329 - val_mse: 0.0658
#
# Epoch 00026: val_loss improved from 0.03334 to 0.03288, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 27/50
# 239/239 [==============================] - 1s 6ms/step - loss: 2.4078e-04 - mse: 4.8157e-04 - val_loss: 0.0328 - val_mse: 0.0655
#
# Epoch 00027: val_loss improved from 0.03288 to 0.03275, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 28/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.3754e-04 - mse: 4.7507e-04 - val_loss: 0.0324 - val_mse: 0.0648
#
# Epoch 00028: val_loss improved from 0.03275 to 0.03238, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 29/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.3563e-04 - mse: 4.7126e-04 - val_loss: 0.0321 - val_mse: 0.0642
#
# Epoch 00029: val_loss improved from 0.03238 to 0.03209, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 30/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.3074e-04 - mse: 4.6149e-04 - val_loss: 0.0325 - val_mse: 0.0649
#
# Epoch 00030: val_loss did not improve from 0.03209
# Epoch 31/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.2726e-04 - mse: 4.5452e-04 - val_loss: 0.0316 - val_mse: 0.0632
#
# Epoch 00031: val_loss improved from 0.03209 to 0.03160, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 32/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.2438e-04 - mse: 4.4875e-04 - val_loss: 0.0319 - val_mse: 0.0638
#
# Epoch 00032: val_loss did not improve from 0.03160
# Epoch 33/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.2202e-04 - mse: 4.4405e-04 - val_loss: 0.0310 - val_mse: 0.0619
#
# Epoch 00033: val_loss improved from 0.03160 to 0.03096, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 34/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.1743e-04 - mse: 4.3486e-04 - val_loss: 0.0308 - val_mse: 0.0616
#
# Epoch 00034: val_loss improved from 0.03096 to 0.03080, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 35/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.1634e-04 - mse: 4.3268e-04 - val_loss: 0.0305 - val_mse: 0.0609
#
# Epoch 00035: val_loss improved from 0.03080 to 0.03047, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 36/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.1199e-04 - mse: 4.2397e-04 - val_loss: 0.0303 - val_mse: 0.0606
#
# Epoch 00036: val_loss improved from 0.03047 to 0.03028, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 37/50
# 239/239 [==============================] - 1s 6ms/step - loss: 2.0990e-04 - mse: 4.1980e-04 - val_loss: 0.0299 - val_mse: 0.0599
#
# Epoch 00037: val_loss improved from 0.03028 to 0.02993, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 38/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.0679e-04 - mse: 4.1358e-04 - val_loss: 0.0297 - val_mse: 0.0593
#
# Epoch 00038: val_loss improved from 0.02993 to 0.02966, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 39/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.0353e-04 - mse: 4.0706e-04 - val_loss: 0.0294 - val_mse: 0.0587
#
# Epoch 00039: val_loss improved from 0.02966 to 0.02935, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 40/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.0097e-04 - mse: 4.0194e-04 - val_loss: 0.0291 - val_mse: 0.0582
#
# Epoch 00040: val_loss improved from 0.02935 to 0.02909, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 41/50
# 239/239 [==============================] - 1s 5ms/step - loss: 1.9852e-04 - mse: 3.9705e-04 - val_loss: 0.0288 - val_mse: 0.0575
#
# Epoch 00041: val_loss improved from 0.02909 to 0.02876, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 42/50
# 239/239 [==============================] - 1s 5ms/step - loss: 1.9497e-04 - mse: 3.8993e-04 - val_loss: 0.0285 - val_mse: 0.0571
#
# Epoch 00042: val_loss improved from 0.02876 to 0.02854, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 43/50
# 239/239 [==============================] - 1s 6ms/step - loss: 1.9304e-04 - mse: 3.8608e-04 - val_loss: 0.0282 - val_mse: 0.0565
#
# Epoch 00043: val_loss improved from 0.02854 to 0.02823, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 44/50
# 239/239 [==============================] - 1s 5ms/step - loss: 1.8976e-04 - mse: 3.7951e-04 - val_loss: 0.0280 - val_mse: 0.0561
#
# Epoch 00044: val_loss improved from 0.02823 to 0.02803, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 45/50
# 239/239 [==============================] - 1s 5ms/step - loss: 1.8900e-04 - mse: 3.7800e-04 - val_loss: 0.0277 - val_mse: 0.0554
#
# Epoch 00045: val_loss improved from 0.02803 to 0.02771, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 46/50
# 239/239 [==============================] - 1s 5ms/step - loss: 1.8617e-04 - mse: 3.7234e-04 - val_loss: 0.0275 - val_mse: 0.0550
#
# Epoch 00046: val_loss improved from 0.02771 to 0.02748, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 47/50
# 239/239 [==============================] - 1s 5ms/step - loss: 1.8512e-04 - mse: 3.7024e-04 - val_loss: 0.0273 - val_mse: 0.0545
#
# Epoch 00047: val_loss improved from 0.02748 to 0.02727, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 48/50
# 239/239 [==============================] - 1s 6ms/step - loss: 1.8351e-04 - mse: 3.6702e-04 - val_loss: 0.0266 - val_mse: 0.0533
#
# Epoch 00048: val_loss improved from 0.02727 to 0.02665, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 49/50
# 239/239 [==============================] - 1s 5ms/step - loss: 1.8127e-04 - mse: 3.6253e-04 - val_loss: 0.0264 - val_mse: 0.0529
#
# Epoch 00049: val_loss improved from 0.02665 to 0.02644, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 50/50
# 239/239 [==============================] - 1s 5ms/step - loss: 1.7938e-04 - mse: 3.5876e-04 - val_loss: 0.0261 - val_mse: 0.0522
#
# Epoch 00050: val_loss improved from 0.02644 to 0.02609, saving model to tmp2\Clothingckeckpointer.ckpt
# Epoch 1/50
# 239/239 [==============================] - 3s 6ms/step - loss: 0.0012 - mse: 0.0025 - val_loss: 0.0294 - val_mse: 0.0588
#
# Epoch 00001: val_loss improved from inf to 0.02938, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0021 - mse: 0.0042 - val_loss: 0.0249 - val_mse: 0.0498
#
# Epoch 00002: val_loss improved from 0.02938 to 0.02489, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 3/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0015 - mse: 0.0030 - val_loss: 0.0253 - val_mse: 0.0506
#
# Epoch 00003: val_loss did not improve from 0.02489
# Epoch 4/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0010 - mse: 0.0021 - val_loss: 0.0249 - val_mse: 0.0498
#
# Epoch 00004: val_loss improved from 0.02489 to 0.02489, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 5/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.5588e-04 - mse: 0.0013 - val_loss: 0.0251 - val_mse: 0.0503
#
# Epoch 00005: val_loss did not improve from 0.02489
# Epoch 6/50
# 239/239 [==============================] - 1s 5ms/step - loss: 7.5708e-04 - mse: 0.0015 - val_loss: 0.0216 - val_mse: 0.0433
#
# Epoch 00006: val_loss improved from 0.02489 to 0.02163, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 7/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.1641e-04 - mse: 0.0012 - val_loss: 0.0212 - val_mse: 0.0424
#
# Epoch 00007: val_loss improved from 0.02163 to 0.02121, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 8/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.5322e-04 - mse: 0.0011 - val_loss: 0.0192 - val_mse: 0.0385
#
# Epoch 00008: val_loss improved from 0.02121 to 0.01924, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 9/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.5230e-04 - mse: 0.0011 - val_loss: 0.0183 - val_mse: 0.0367
#
# Epoch 00009: val_loss improved from 0.01924 to 0.01834, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 10/50
# 239/239 [==============================] - 1s 6ms/step - loss: 4.8908e-04 - mse: 9.7815e-04 - val_loss: 0.0177 - val_mse: 0.0354
#
# Epoch 00010: val_loss improved from 0.01834 to 0.01769, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 11/50
# 239/239 [==============================] - 1s 5ms/step - loss: 4.7110e-04 - mse: 9.4219e-04 - val_loss: 0.0170 - val_mse: 0.0340
#
# Epoch 00011: val_loss improved from 0.01769 to 0.01699, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 12/50
# 239/239 [==============================] - 1s 5ms/step - loss: 4.3945e-04 - mse: 8.7889e-04 - val_loss: 0.0165 - val_mse: 0.0331
#
# Epoch 00012: val_loss improved from 0.01699 to 0.01655, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 13/50
# 239/239 [==============================] - 1s 5ms/step - loss: 4.3224e-04 - mse: 8.6448e-04 - val_loss: 0.0160 - val_mse: 0.0321
#
# Epoch 00013: val_loss improved from 0.01655 to 0.01605, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 14/50
# 239/239 [==============================] - 1s 5ms/step - loss: 4.2214e-04 - mse: 8.4429e-04 - val_loss: 0.0157 - val_mse: 0.0314
#
# Epoch 00014: val_loss improved from 0.01605 to 0.01570, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 15/50
# 239/239 [==============================] - 1s 5ms/step - loss: 4.0907e-04 - mse: 8.1815e-04 - val_loss: 0.0153 - val_mse: 0.0306
#
# Epoch 00015: val_loss improved from 0.01570 to 0.01530, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 16/50
# 239/239 [==============================] - 1s 6ms/step - loss: 3.9065e-04 - mse: 7.8131e-04 - val_loss: 0.0149 - val_mse: 0.0298
#
# Epoch 00016: val_loss improved from 0.01530 to 0.01491, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 17/50
# 239/239 [==============================] - 1s 5ms/step - loss: 3.8838e-04 - mse: 7.7676e-04 - val_loss: 0.0147 - val_mse: 0.0294
#
# Epoch 00017: val_loss improved from 0.01491 to 0.01471, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 18/50
# 239/239 [==============================] - 1s 5ms/step - loss: 3.7599e-04 - mse: 7.5198e-04 - val_loss: 0.0144 - val_mse: 0.0287
#
# Epoch 00018: val_loss improved from 0.01471 to 0.01437, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 19/50
# 239/239 [==============================] - 1s 5ms/step - loss: 3.6883e-04 - mse: 7.3766e-04 - val_loss: 0.0142 - val_mse: 0.0284
#
# Epoch 00019: val_loss improved from 0.01437 to 0.01418, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 20/50
# 239/239 [==============================] - 1s 5ms/step - loss: 3.5016e-04 - mse: 7.0032e-04 - val_loss: 0.0139 - val_mse: 0.0278
#
# Epoch 00020: val_loss improved from 0.01418 to 0.01389, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 21/50
# 239/239 [==============================] - 1s 5ms/step - loss: 3.4708e-04 - mse: 6.9415e-04 - val_loss: 0.0137 - val_mse: 0.0273
#
# Epoch 00021: val_loss improved from 0.01389 to 0.01367, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 22/50
# 239/239 [==============================] - 1s 6ms/step - loss: 3.3844e-04 - mse: 6.7689e-04 - val_loss: 0.0134 - val_mse: 0.0268
#
# Epoch 00022: val_loss improved from 0.01367 to 0.01340, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 23/50
# 239/239 [==============================] - 1s 5ms/step - loss: 3.3549e-04 - mse: 6.7098e-04 - val_loss: 0.0132 - val_mse: 0.0264
#
# Epoch 00023: val_loss improved from 0.01340 to 0.01321, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 24/50
# 239/239 [==============================] - 1s 6ms/step - loss: 3.3316e-04 - mse: 6.6632e-04 - val_loss: 0.0130 - val_mse: 0.0260
#
# Epoch 00024: val_loss improved from 0.01321 to 0.01300, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 25/50
# 239/239 [==============================] - 1s 6ms/step - loss: 3.2510e-04 - mse: 6.5020e-04 - val_loss: 0.0128 - val_mse: 0.0256
#
# Epoch 00025: val_loss improved from 0.01300 to 0.01280, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 26/50
# 239/239 [==============================] - 1s 6ms/step - loss: 3.2183e-04 - mse: 6.4366e-04 - val_loss: 0.0126 - val_mse: 0.0252
#
# Epoch 00026: val_loss improved from 0.01280 to 0.01261, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 27/50
# 239/239 [==============================] - 1s 5ms/step - loss: 3.1394e-04 - mse: 6.2788e-04 - val_loss: 0.0124 - val_mse: 0.0249
#
# Epoch 00027: val_loss improved from 0.01261 to 0.01243, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 28/50
# 239/239 [==============================] - 1s 6ms/step - loss: 3.1051e-04 - mse: 6.2103e-04 - val_loss: 0.0122 - val_mse: 0.0245
#
# Epoch 00028: val_loss improved from 0.01243 to 0.01224, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 29/50
# 239/239 [==============================] - 1s 6ms/step - loss: 3.0501e-04 - mse: 6.1003e-04 - val_loss: 0.0121 - val_mse: 0.0241
#
# Epoch 00029: val_loss improved from 0.01224 to 0.01207, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 30/50
# 239/239 [==============================] - 2s 8ms/step - loss: 2.9872e-04 - mse: 5.9744e-04 - val_loss: 0.0119 - val_mse: 0.0238
#
# Epoch 00030: val_loss improved from 0.01207 to 0.01190, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 31/50
# 239/239 [==============================] - 2s 8ms/step - loss: 2.9402e-04 - mse: 5.8803e-04 - val_loss: 0.0117 - val_mse: 0.0234
#
# Epoch 00031: val_loss improved from 0.01190 to 0.01172, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 32/50
# 239/239 [==============================] - 2s 6ms/step - loss: 2.8908e-04 - mse: 5.7815e-04 - val_loss: 0.0115 - val_mse: 0.0231
#
# Epoch 00032: val_loss improved from 0.01172 to 0.01153, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 33/50
# 239/239 [==============================] - 1s 6ms/step - loss: 2.8549e-04 - mse: 5.7097e-04 - val_loss: 0.0113 - val_mse: 0.0227
#
# Epoch 00033: val_loss improved from 0.01153 to 0.01134, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 34/50
# 239/239 [==============================] - 1s 6ms/step - loss: 2.8163e-04 - mse: 5.6326e-04 - val_loss: 0.0112 - val_mse: 0.0223
#
# Epoch 00034: val_loss improved from 0.01134 to 0.01117, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 35/50
# 239/239 [==============================] - 1s 6ms/step - loss: 2.7612e-04 - mse: 5.5223e-04 - val_loss: 0.0110 - val_mse: 0.0220
#
# Epoch 00035: val_loss improved from 0.01117 to 0.01100, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 36/50
# 239/239 [==============================] - 1s 6ms/step - loss: 2.7117e-04 - mse: 5.4235e-04 - val_loss: 0.0108 - val_mse: 0.0216
#
# Epoch 00036: val_loss improved from 0.01100 to 0.01080, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 37/50
# 239/239 [==============================] - 1s 6ms/step - loss: 2.6878e-04 - mse: 5.3757e-04 - val_loss: 0.0106 - val_mse: 0.0212
#
# Epoch 00037: val_loss improved from 0.01080 to 0.01059, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 38/50
# 239/239 [==============================] - 1s 6ms/step - loss: 2.6409e-04 - mse: 5.2818e-04 - val_loss: 0.0104 - val_mse: 0.0208
#
# Epoch 00038: val_loss improved from 0.01059 to 0.01040, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 39/50
# 239/239 [==============================] - 1s 6ms/step - loss: 2.6053e-04 - mse: 5.2106e-04 - val_loss: 0.0102 - val_mse: 0.0204
#
# Epoch 00039: val_loss improved from 0.01040 to 0.01022, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 40/50
# 239/239 [==============================] - 1s 6ms/step - loss: 2.5080e-04 - mse: 5.0160e-04 - val_loss: 0.0100 - val_mse: 0.0199
#
# Epoch 00040: val_loss improved from 0.01022 to 0.00996, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 41/50
# 239/239 [==============================] - 2s 7ms/step - loss: 2.5343e-04 - mse: 5.0686e-04 - val_loss: 0.0098 - val_mse: 0.0196
#
# Epoch 00041: val_loss improved from 0.00996 to 0.00980, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 42/50
# 239/239 [==============================] - 1s 6ms/step - loss: 2.4048e-04 - mse: 4.8097e-04 - val_loss: 0.0095 - val_mse: 0.0191
#
# Epoch 00042: val_loss improved from 0.00980 to 0.00954, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 43/50
# 239/239 [==============================] - 1s 6ms/step - loss: 2.4078e-04 - mse: 4.8156e-04 - val_loss: 0.0094 - val_mse: 0.0187
#
# Epoch 00043: val_loss improved from 0.00954 to 0.00935, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 44/50
# 239/239 [==============================] - 1s 6ms/step - loss: 2.3780e-04 - mse: 4.7560e-04 - val_loss: 0.0092 - val_mse: 0.0183
#
# Epoch 00044: val_loss improved from 0.00935 to 0.00916, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 45/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.3375e-04 - mse: 4.6750e-04 - val_loss: 0.0089 - val_mse: 0.0179
# Epoch 00045: val_loss improved from 0.00916 to 0.00894, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 46/50
# 239/239 [==============================] - 1s 6ms/step - loss: 2.2985e-04 - mse: 4.5971e-04 - val_loss: 0.0087 - val_mse: 0.0175
#
# Epoch 00046: val_loss improved from 0.00894 to 0.00873, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 47/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.2026e-04 - mse: 4.4052e-04 - val_loss: 0.0084 - val_mse: 0.0169
#
# Epoch 00047: val_loss improved from 0.00873 to 0.00843, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 48/50
# 239/239 [==============================] - 1s 6ms/step - loss: 2.1490e-04 - mse: 4.2979e-04 - val_loss: 0.0081 - val_mse: 0.0163
#
# Epoch 00048: val_loss improved from 0.00843 to 0.00814, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 49/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.0964e-04 - mse: 4.1928e-04 - val_loss: 0.0078 - val_mse: 0.0157
#
# Epoch 00049: val_loss improved from 0.00814 to 0.00784, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 50/50
# 239/239 [==============================] - 1s 6ms/step - loss: 2.0577e-04 - mse: 4.1154e-04 - val_loss: 0.0075 - val_mse: 0.0151
#
# Epoch 00050: val_loss improved from 0.00784 to 0.00755, saving model to tmp2\Chemicalckeckpointer.ckpt
# Epoch 1/50
# 239/239 [==============================] - 4s 8ms/step - loss: 0.0015 - mse: 0.0030 - val_loss: 0.0382 - val_mse: 0.0764
#
# Epoch 00001: val_loss improved from inf to 0.03819, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0023 - mse: 0.0047 - val_loss: 0.0388 - val_mse: 0.0776
#
# Epoch 00002: val_loss did not improve from 0.03819
# Epoch 3/50
# 239/239 [==============================] - 1s 6ms/step - loss: 0.0018 - mse: 0.0036 - val_loss: 0.0352 - val_mse: 0.0704
#
# Epoch 00003: val_loss improved from 0.03819 to 0.03520, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 4/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0019 - mse: 0.0039 - val_loss: 0.0314 - val_mse: 0.0627
#
# Epoch 00004: val_loss improved from 0.03520 to 0.03135, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 5/50
# 239/239 [==============================] - 1s 6ms/step - loss: 0.0016 - mse: 0.0032 - val_loss: 0.0286 - val_mse: 0.0572
#
# Epoch 00005: val_loss improved from 0.03135 to 0.02859, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 6/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0015 - mse: 0.0031 - val_loss: 0.0265 - val_mse: 0.0530
#
# Epoch 00006: val_loss improved from 0.02859 to 0.02652, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 7/50
# 239/239 [==============================] - 1s 6ms/step - loss: 0.0013 - mse: 0.0026 - val_loss: 0.0249 - val_mse: 0.0497
#
# Epoch 00007: val_loss improved from 0.02652 to 0.02487, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 8/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0012 - mse: 0.0024 - val_loss: 0.0238 - val_mse: 0.0475
#
# Epoch 00008: val_loss improved from 0.02487 to 0.02376, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 9/50
# 239/239 [==============================] - 1s 6ms/step - loss: 0.0011 - mse: 0.0023 - val_loss: 0.0228 - val_mse: 0.0457
#
# Epoch 00009: val_loss improved from 0.02376 to 0.02284, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 10/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0011 - mse: 0.0021 - val_loss: 0.0221 - val_mse: 0.0441
#
# Epoch 00010: val_loss improved from 0.02284 to 0.02206, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 11/50
# 239/239 [==============================] - 1s 6ms/step - loss: 0.0010 - mse: 0.0020 - val_loss: 0.0214 - val_mse: 0.0427
#
# Epoch 00011: val_loss improved from 0.02206 to 0.02136, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 12/50
# 239/239 [==============================] - 1s 5ms/step - loss: 9.6879e-04 - mse: 0.0019 - val_loss: 0.0207 - val_mse: 0.0413
#
# Epoch 00012: val_loss improved from 0.02136 to 0.02066, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 13/50
# 239/239 [==============================] - 1s 6ms/step - loss: 9.1725e-04 - mse: 0.0018 - val_loss: 0.0200 - val_mse: 0.0400
#
# Epoch 00013: val_loss improved from 0.02066 to 0.01999, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 14/50
# 239/239 [==============================] - 1s 5ms/step - loss: 8.7468e-04 - mse: 0.0017 - val_loss: 0.0194 - val_mse: 0.0388
#
# Epoch 00014: val_loss improved from 0.01999 to 0.01940, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 15/50
# 239/239 [==============================] - 1s 6ms/step - loss: 8.3931e-04 - mse: 0.0017 - val_loss: 0.0188 - val_mse: 0.0377
#
# Epoch 00015: val_loss improved from 0.01940 to 0.01883, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 16/50
# 239/239 [==============================] - 1s 5ms/step - loss: 8.0428e-04 - mse: 0.0016 - val_loss: 0.0183 - val_mse: 0.0366
#
# Epoch 00016: val_loss improved from 0.01883 to 0.01830, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 17/50
# 239/239 [==============================] - 1s 6ms/step - loss: 7.7536e-04 - mse: 0.0016 - val_loss: 0.0178 - val_mse: 0.0357
#
# Epoch 00017: val_loss improved from 0.01830 to 0.01783, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 18/50
# 239/239 [==============================] - 1s 5ms/step - loss: 7.5032e-04 - mse: 0.0015 - val_loss: 0.0174 - val_mse: 0.0348
#
# Epoch 00018: val_loss improved from 0.01783 to 0.01741, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 19/50
# 239/239 [==============================] - 1s 6ms/step - loss: 7.3111e-04 - mse: 0.0015 - val_loss: 0.0171 - val_mse: 0.0342
#
# Epoch 00019: val_loss improved from 0.01741 to 0.01708, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 20/50
# 239/239 [==============================] - 1s 5ms/step - loss: 7.1382e-04 - mse: 0.0014 - val_loss: 0.0168 - val_mse: 0.0335
#
# Epoch 00020: val_loss improved from 0.01708 to 0.01676, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 21/50
# 239/239 [==============================] - 1s 6ms/step - loss: 6.9774e-04 - mse: 0.0014 - val_loss: 0.0165 - val_mse: 0.0329
#
# Epoch 00021: val_loss improved from 0.01676 to 0.01645, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 22/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.8502e-04 - mse: 0.0014 - val_loss: 0.0162 - val_mse: 0.0324
#
# Epoch 00022: val_loss improved from 0.01645 to 0.01622, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 23/50
# 239/239 [==============================] - 1s 6ms/step - loss: 6.7647e-04 - mse: 0.0014 - val_loss: 0.0162 - val_mse: 0.0323
#
# Epoch 00023: val_loss improved from 0.01622 to 0.01617, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 24/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.6551e-04 - mse: 0.0013 - val_loss: 0.0160 - val_mse: 0.0319
#
# Epoch 00024: val_loss improved from 0.01617 to 0.01595, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 25/50
# 239/239 [==============================] - 1s 6ms/step - loss: 6.4994e-04 - mse: 0.0013 - val_loss: 0.0156 - val_mse: 0.0312
#
# Epoch 00025: val_loss improved from 0.01595 to 0.01562, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 26/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.3418e-04 - mse: 0.0013 - val_loss: 0.0153 - val_mse: 0.0306
#
# Epoch 00026: val_loss improved from 0.01562 to 0.01528, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 27/50
# 239/239 [==============================] - 1s 6ms/step - loss: 6.2005e-04 - mse: 0.0012 - val_loss: 0.0150 - val_mse: 0.0299
#
# Epoch 00027: val_loss improved from 0.01528 to 0.01496, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 28/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.0732e-04 - mse: 0.0012 - val_loss: 0.0147 - val_mse: 0.0293
#
# Epoch 00028: val_loss improved from 0.01496 to 0.01467, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 29/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.9619e-04 - mse: 0.0012 - val_loss: 0.0144 - val_mse: 0.0288
#
# Epoch 00029: val_loss improved from 0.01467 to 0.01438, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 30/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.8666e-04 - mse: 0.0012 - val_loss: 0.0142 - val_mse: 0.0283
#
# Epoch 00030: val_loss improved from 0.01438 to 0.01415, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 31/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.7858e-04 - mse: 0.0012 - val_loss: 0.0139 - val_mse: 0.0278
#
# Epoch 00031: val_loss improved from 0.01415 to 0.01391, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 32/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.6548e-04 - mse: 0.0011 - val_loss: 0.0135 - val_mse: 0.0270
#
# Epoch 00032: val_loss improved from 0.01391 to 0.01348, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 33/50
# 239/239 [==============================] - 1s 6ms/step - loss: 5.5433e-04 - mse: 0.0011 - val_loss: 0.0135 - val_mse: 0.0270
#
# Epoch 00033: val_loss did not improve from 0.01348
# Epoch 34/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.5151e-04 - mse: 0.0011 - val_loss: 0.0135 - val_mse: 0.0269
#
# Epoch 00034: val_loss improved from 0.01348 to 0.01347, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 35/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.4827e-04 - mse: 0.0011 - val_loss: 0.0134 - val_mse: 0.0268
#
# Epoch 00035: val_loss improved from 0.01347 to 0.01342, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 36/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.4499e-04 - mse: 0.0011 - val_loss: 0.0134 - val_mse: 0.0267
#
# Epoch 00036: val_loss improved from 0.01342 to 0.01337, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 37/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.4160e-04 - mse: 0.0011 - val_loss: 0.0133 - val_mse: 0.0267
#
# Epoch 00037: val_loss improved from 0.01337 to 0.01333, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 38/50
# 239/239 [==============================] - 1s 6ms/step - loss: 5.3832e-04 - mse: 0.0011 - val_loss: 0.0133 - val_mse: 0.0265
#
# Epoch 00038: val_loss improved from 0.01333 to 0.01327, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 39/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.3476e-04 - mse: 0.0011 - val_loss: 0.0132 - val_mse: 0.0264
#
# Epoch 00039: val_loss improved from 0.01327 to 0.01320, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 40/50
# 239/239 [==============================] - 1s 6ms/step - loss: 5.3119e-04 - mse: 0.0011 - val_loss: 0.0131 - val_mse: 0.0263
#
# Epoch 00040: val_loss improved from 0.01320 to 0.01314, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 41/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.2807e-04 - mse: 0.0011 - val_loss: 0.0131 - val_mse: 0.0262
#
# Epoch 00041: val_loss improved from 0.01314 to 0.01308, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 42/50
# 239/239 [==============================] - 1s 6ms/step - loss: 5.2409e-04 - mse: 0.0010 - val_loss: 0.0130 - val_mse: 0.0260
#
# Epoch 00042: val_loss improved from 0.01308 to 0.01302, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 43/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.2068e-04 - mse: 0.0010 - val_loss: 0.0129 - val_mse: 0.0259
#
# Epoch 00043: val_loss improved from 0.01302 to 0.01295, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 44/50
# 239/239 [==============================] - 1s 6ms/step - loss: 5.1769e-04 - mse: 0.0010 - val_loss: 0.0129 - val_mse: 0.0258
#
# Epoch 00044: val_loss improved from 0.01295 to 0.01289, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 45/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.1313e-04 - mse: 0.0010 - val_loss: 0.0128 - val_mse: 0.0256
#
# Epoch 00045: val_loss improved from 0.01289 to 0.01282, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 46/50
# 239/239 [==============================] - 1s 6ms/step - loss: 5.1040e-04 - mse: 0.0010 - val_loss: 0.0127 - val_mse: 0.0255
#
# Epoch 00046: val_loss improved from 0.01282 to 0.01275, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 47/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.0677e-04 - mse: 0.0010 - val_loss: 0.0127 - val_mse: 0.0254
#
# Epoch 00047: val_loss improved from 0.01275 to 0.01268, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 48/50
# 239/239 [==============================] - 1s 6ms/step - loss: 5.0278e-04 - mse: 0.0010 - val_loss: 0.0126 - val_mse: 0.0252
#
# Epoch 00048: val_loss improved from 0.01268 to 0.01261, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 49/50
# 239/239 [==============================] - 1s 5ms/step - loss: 4.9918e-04 - mse: 9.9835e-04 - val_loss: 0.0125 - val_mse: 0.0251
#
# Epoch 00049: val_loss improved from 0.01261 to 0.01253, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 50/50
# 239/239 [==============================] - 1s 6ms/step - loss: 4.9492e-04 - mse: 9.8984e-04 - val_loss: 0.0125 - val_mse: 0.0249
#
# Epoch 00050: val_loss improved from 0.01253 to 0.01247, saving model to tmp2\Medicineckeckpointer.ckpt
# Epoch 1/50
# 239/239 [==============================] - 3s 6ms/step - loss: 4.4710e-04 - mse: 8.9419e-04 - val_loss: 0.0538 - val_mse: 0.1076
#
# Epoch 00001: val_loss improved from inf to 0.05381, saving model to tmp2\Non_Metalckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 5ms/step - loss: 7.3531e-04 - mse: 0.0015 - val_loss: 0.0526 - val_mse: 0.1052
#
# Epoch 00002: val_loss improved from 0.05381 to 0.05260, saving model to tmp2\Non_Metalckeckpointer.ckpt
# Epoch 3/50
# 239/239 [==============================] - 1s 6ms/step - loss: 6.6320e-04 - mse: 0.0013 - val_loss: 0.0550 - val_mse: 0.1100
#
# Epoch 00003: val_loss did not improve from 0.05260
# Epoch 4/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.0430e-04 - mse: 0.0010 - val_loss: 0.0485 - val_mse: 0.0970
#
# Epoch 00004: val_loss improved from 0.05260 to 0.04848, saving model to tmp2\Non_Metalckeckpointer.ckpt
# Epoch 5/50
# 239/239 [==============================] - 1s 6ms/step - loss: 3.3842e-04 - mse: 6.7685e-04 - val_loss: 0.0403 - val_mse: 0.0806
#
# Epoch 00005: val_loss improved from 0.04848 to 0.04031, saving model to tmp2\Non_Metalckeckpointer.ckpt
# Epoch 6/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.6165e-04 - mse: 5.2330e-04 - val_loss: 0.0354 - val_mse: 0.0709
#
# Epoch 00006: val_loss improved from 0.04031 to 0.03544, saving model to tmp2\Non_Metalckeckpointer.ckpt
# Epoch 7/50
# 239/239 [==============================] - 1s 6ms/step - loss: 2.2807e-04 - mse: 4.5614e-04 - val_loss: 0.0344 - val_mse: 0.0688
#
# Epoch 00007: val_loss improved from 0.03544 to 0.03440, saving model to tmp2\Non_Metalckeckpointer.ckpt
# Epoch 8/50
# 239/239 [==============================] - 1s 5ms/step - loss: 2.1468e-04 - mse: 4.2937e-04 - val_loss: 0.0325 - val_mse: 0.0651
#
# ...
# Epoch 31/50
# 239/239 [==============================] - 1s 5ms/step - loss: 8.6933e-05 - mse: 1.7387e-04 - val_loss: 0.0052 - val_mse: 0.0104
#
# Epoch 00031: val_loss did not improve from 0.00504
# Epoch 32/50
# 239/239 [==============================] - 1s 5ms/step - loss: 8.4967e-05 - mse: 1.6993e-04 - val_loss: 0.0055 - val_mse: 0.0111
#
# Epoch 00032: val_loss did not improve from 0.00504
# Epoch 33/50
# 239/239 [==============================] - 1s 5ms/step - loss: 8.5257e-05 - mse: 1.7051e-04 - val_loss: 0.0054 - val_mse: 0.0108
#
# Epoch 00033: val_loss did not improve from 0.00504
# Epoch 34/50
# 239/239 [==============================] - 1s 5ms/step - loss: 8.2519e-05 - mse: 1.6504e-04 - val_loss: 0.0052 - val_mse: 0.0103
#
# Epoch 00034: val_loss did not improve from 0.00504
# Epoch 35/50
# 239/239 [==============================] - 1s 5ms/step - loss: 8.0966e-05 - mse: 1.6193e-04 - val_loss: 0.0057 - val_mse: 0.0114
#
# Epoch 00035: val_loss did not improve from 0.00504
# Epoch 36/50
# 239/239 [==============================] - 1s 5ms/step - loss: 7.5918e-05 - mse: 1.5184e-04 - val_loss: 0.0047 - val_mse: 0.0094
#
# Epoch 00036: val_loss improved from 0.00504 to 0.00470, saving model to tmp2\Serviceckeckpointer.ckpt
# Epoch 37/50
# 239/239 [==============================] - 1s 5ms/step - loss: 7.4324e-05 - mse: 1.4865e-04 - val_loss: 0.0051 - val_mse: 0.0102
#
# Epoch 00037: val_loss did not improve from 0.00470
# Epoch 38/50
# 239/239 [==============================] - 1s 5ms/step - loss: 7.0917e-05 - mse: 1.4183e-04 - val_loss: 0.0048 - val_mse: 0.0097
#
# Epoch 00038: val_loss did not improve from 0.00470
# Epoch 39/50
# 239/239 [==============================] - 1s 5ms/step - loss: 7.0057e-05 - mse: 1.4011e-04 - val_loss: 0.0051 - val_mse: 0.0103
#
# Epoch 00039: val_loss did not improve from 0.00470
# Epoch 40/50
# 239/239 [==============================] - 1s 5ms/step - loss: 7.6001e-05 - mse: 1.5200e-04 - val_loss: 0.0053 - val_mse: 0.0106
#
# Epoch 00040: val_loss did not improve from 0.00470
# Epoch 41/50
# 239/239 [==============================] - 1s 5ms/step - loss: 7.3833e-05 - mse: 1.4767e-04 - val_loss: 0.0047 - val_mse: 0.0094
#
# Epoch 00041: val_loss improved from 0.00470 to 0.00470, saving model to tmp2\Serviceckeckpointer.ckpt
# Epoch 42/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.9532e-05 - mse: 1.3906e-04 - val_loss: 0.0048 - val_mse: 0.0097
#
# Epoch 00042: val_loss did not improve from 0.00470
# Epoch 43/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.5475e-05 - mse: 1.3095e-04 - val_loss: 0.0045 - val_mse: 0.0089
#
# Epoch 00043: val_loss improved from 0.00470 to 0.00447, saving model to tmp2\Serviceckeckpointer.ckpt
# Epoch 44/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.3806e-05 - mse: 1.2761e-04 - val_loss: 0.0047 - val_mse: 0.0094
#
# Epoch 00044: val_loss did not improve from 0.00447
# Epoch 45/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.3477e-05 - mse: 1.2695e-04 - val_loss: 0.0052 - val_mse: 0.0103
#
# Epoch 00045: val_loss did not improve from 0.00447
# Epoch 46/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.4276e-05 - mse: 1.2855e-04 - val_loss: 0.0055 - val_mse: 0.0109
#
# Epoch 00046: val_loss did not improve from 0.00447
# Epoch 47/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.6207e-05 - mse: 1.3241e-04 - val_loss: 0.0059 - val_mse: 0.0118
#
# Epoch 00047: val_loss did not improve from 0.00447
# Epoch 48/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.8721e-05 - mse: 1.3744e-04 - val_loss: 0.0054 - val_mse: 0.0108
#
# Epoch 00048: val_loss did not improve from 0.00447
# Epoch 49/50
# 239/239 [==============================] - 1s 5ms/step - loss: 6.3387e-05 - mse: 1.2677e-04 - val_loss: 0.0050 - val_mse: 0.0100
#
# Epoch 00049: val_loss did not improve from 0.00447
# Epoch 50/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.7518e-05 - mse: 1.1504e-04 - val_loss: 0.0051 - val_mse: 0.0102
#
# Epoch 00050: val_loss did not improve from 0.00447
# Epoch 1/50
# 239/239 [==============================] - 4s 8ms/step - loss: 0.0025 - mse: 0.0051 - val_loss: 0.0154 - val_mse: 0.0307
#
# Epoch 00001: val_loss improved from inf to 0.01536, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0018 - mse: 0.0037 - val_loss: 0.0154 - val_mse: 0.0307
#
# Epoch 00002: val_loss did not improve from 0.01536
# Epoch 3/50
# 239/239 [==============================] - 2s 7ms/step - loss: 0.0016 - mse: 0.0031 - val_loss: 0.0126 - val_mse: 0.0252
#
# Epoch 00003: val_loss improved from 0.01536 to 0.01260, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 4/50
# 239/239 [==============================] - 1s 6ms/step - loss: 0.0014 - mse: 0.0027 - val_loss: 0.0117 - val_mse: 0.0233
#
# Epoch 00004: val_loss improved from 0.01260 to 0.01166, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 5/50
# 239/239 [==============================] - 2s 6ms/step - loss: 0.0013 - mse: 0.0025 - val_loss: 0.0107 - val_mse: 0.0215
#
# Epoch 00005: val_loss improved from 0.01166 to 0.01073, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 6/50
# 239/239 [==============================] - 2s 7ms/step - loss: 0.0012 - mse: 0.0023 - val_loss: 0.0099 - val_mse: 0.0199
#
# Epoch 00006: val_loss improved from 0.01073 to 0.00993, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 7/50
# 239/239 [==============================] - 1s 6ms/step - loss: 0.0011 - mse: 0.0021 - val_loss: 0.0086 - val_mse: 0.0172
#
# Epoch 00007: val_loss improved from 0.00993 to 0.00859, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 8/50
# 239/239 [==============================] - 1s 6ms/step - loss: 9.7108e-04 - mse: 0.0019 - val_loss: 0.0079 - val_mse: 0.0157
#
# Epoch 00008: val_loss improved from 0.00859 to 0.00787, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 9/50
# 239/239 [==============================] - 1s 6ms/step - loss: 9.0835e-04 - mse: 0.0018 - val_loss: 0.0072 - val_mse: 0.0144
#
# Epoch 00009: val_loss improved from 0.00787 to 0.00721, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 10/50
# 239/239 [==============================] - 1s 6ms/step - loss: 8.5557e-04 - mse: 0.0017 - val_loss: 0.0066 - val_mse: 0.0133
#
# Epoch 00010: val_loss improved from 0.00721 to 0.00665, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 11/50
# 239/239 [==============================] - 1s 5ms/step - loss: 8.1981e-04 - mse: 0.0016 - val_loss: 0.0063 - val_mse: 0.0126
#
# Epoch 00011: val_loss improved from 0.00665 to 0.00628, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 12/50
# 239/239 [==============================] - 2s 7ms/step - loss: 7.8061e-04 - mse: 0.0016 - val_loss: 0.0059 - val_mse: 0.0117
#
# Epoch 00012: val_loss improved from 0.00628 to 0.00586, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 13/50
# 239/239 [==============================] - 2s 6ms/step - loss: 7.4875e-04 - mse: 0.0015 - val_loss: 0.0055 - val_mse: 0.0110
#
# Epoch 00013: val_loss improved from 0.00586 to 0.00551, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 14/50
# 239/239 [==============================] - 1s 6ms/step - loss: 7.2246e-04 - mse: 0.0014 - val_loss: 0.0052 - val_mse: 0.0105
#
# Epoch 00014: val_loss improved from 0.00551 to 0.00523, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 15/50
# 239/239 [==============================] - 1s 6ms/step - loss: 7.0036e-04 - mse: 0.0014 - val_loss: 0.0050 - val_mse: 0.0100
#
# Epoch 00015: val_loss improved from 0.00523 to 0.00498, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 16/50
# 239/239 [==============================] - 1s 6ms/step - loss: 6.8057e-04 - mse: 0.0014 - val_loss: 0.0048 - val_mse: 0.0096
#
# Epoch 00016: val_loss improved from 0.00498 to 0.00478, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 17/50
# 239/239 [==============================] - 2s 7ms/step - loss: 6.6392e-04 - mse: 0.0013 - val_loss: 0.0046 - val_mse: 0.0092
#
# Epoch 00017: val_loss improved from 0.00478 to 0.00460, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 18/50
# 239/239 [==============================] - 2s 7ms/step - loss: 6.4819e-04 - mse: 0.0013 - val_loss: 0.0045 - val_mse: 0.0089
#
# Epoch 00018: val_loss improved from 0.00460 to 0.00446, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 19/50
# 239/239 [==============================] - 1s 6ms/step - loss: 6.3497e-04 - mse: 0.0013 - val_loss: 0.0043 - val_mse: 0.0086
#
# Epoch 00019: val_loss improved from 0.00446 to 0.00432, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 20/50
# 239/239 [==============================] - 1s 6ms/step - loss: 6.2237e-04 - mse: 0.0012 - val_loss: 0.0042 - val_mse: 0.0084
#
# Epoch 00020: val_loss improved from 0.00432 to 0.00418, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 21/50
# 239/239 [==============================] - 1s 6ms/step - loss: 6.0929e-04 - mse: 0.0012 - val_loss: 0.0041 - val_mse: 0.0081
#
# Epoch 00021: val_loss improved from 0.00418 to 0.00407, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 22/50
# 239/239 [==============================] - 1s 6ms/step - loss: 5.9800e-04 - mse: 0.0012 - val_loss: 0.0040 - val_mse: 0.0080
#
# Epoch 00022: val_loss improved from 0.00407 to 0.00399, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 23/50
# 239/239 [==============================] - 1s 6ms/step - loss: 5.9179e-04 - mse: 0.0012 - val_loss: 0.0036 - val_mse: 0.0072
#
# Epoch 00023: val_loss improved from 0.00399 to 0.00361, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 24/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.2901e-04 - mse: 0.0011 - val_loss: 0.0040 - val_mse: 0.0080
#
# Epoch 00024: val_loss did not improve from 0.00361
# Epoch 25/50
# 239/239 [==============================] - 1s 6ms/step - loss: 5.7811e-04 - mse: 0.0012 - val_loss: 0.0039 - val_mse: 0.0079
#
# Epoch 00025: val_loss did not improve from 0.00361
# Epoch 26/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.7027e-04 - mse: 0.0011 - val_loss: 0.0038 - val_mse: 0.0075
#
# Epoch 00026: val_loss did not improve from 0.00361
# Epoch 27/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.5290e-04 - mse: 0.0011 - val_loss: 0.0036 - val_mse: 0.0072
#
# Epoch 00027: val_loss improved from 0.00361 to 0.00360, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 28/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.3839e-04 - mse: 0.0011 - val_loss: 0.0035 - val_mse: 0.0070
#
# Epoch 00028: val_loss improved from 0.00360 to 0.00348, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 29/50
# 239/239 [==============================] - 1s 5ms/step - loss: 5.2737e-04 - mse: 0.0011 - val_loss: 0.0033 - val_mse: 0.0067
#
# Epoch 00029: val_loss improved from 0.00348 to 0.00334, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 30/50
# 239/239 [==============================] - 1s 6ms/step - loss: 5.1577e-04 - mse: 0.0010 - val_loss: 0.0032 - val_mse: 0.0065
#
# Epoch 00030: val_loss improved from 0.00334 to 0.00324, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 31/50
# 239/239 [==============================] - 1s 6ms/step - loss: 5.0593e-04 - mse: 0.0010 - val_loss: 0.0031 - val_mse: 0.0063
#
# Epoch 00031: val_loss improved from 0.00324 to 0.00314, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 32/50
# 239/239 [==============================] - 1s 6ms/step - loss: 4.9608e-04 - mse: 9.9217e-04 - val_loss: 0.0030 - val_mse: 0.0061
#
# Epoch 00032: val_loss improved from 0.00314 to 0.00304, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 33/50
# 239/239 [==============================] - 1s 5ms/step - loss: 4.8628e-04 - mse: 9.7255e-04 - val_loss: 0.0030 - val_mse: 0.0059
#
# Epoch 00033: val_loss improved from 0.00304 to 0.00295, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 34/50
# 239/239 [==============================] - 1s 5ms/step - loss: 4.7664e-04 - mse: 9.5328e-04 - val_loss: 0.0029 - val_mse: 0.0057
#
# Epoch 00034: val_loss improved from 0.00295 to 0.00285, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 35/50
# 239/239 [==============================] - 2s 6ms/step - loss: 4.6624e-04 - mse: 9.3248e-04 - val_loss: 0.0027 - val_mse: 0.0055
#
# Epoch 00035: val_loss improved from 0.00285 to 0.00274, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 36/50
# 239/239 [==============================] - 1s 6ms/step - loss: 4.5491e-04 - mse: 9.0981e-04 - val_loss: 0.0027 - val_mse: 0.0053
#
# Epoch 00036: val_loss improved from 0.00274 to 0.00266, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 37/50
# 239/239 [==============================] - 1s 6ms/step - loss: 4.4475e-04 - mse: 8.8950e-04 - val_loss: 0.0026 - val_mse: 0.0051
#
# Epoch 00037: val_loss improved from 0.00266 to 0.00257, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 38/50
# 239/239 [==============================] - 2s 6ms/step - loss: 4.3361e-04 - mse: 8.6723e-04 - val_loss: 0.0025 - val_mse: 0.0050
#
# Epoch 00038: val_loss improved from 0.00257 to 0.00249, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 39/50
# 239/239 [==============================] - 2s 6ms/step - loss: 4.2283e-04 - mse: 8.4567e-04 - val_loss: 0.0024 - val_mse: 0.0048
#
# Epoch 00039: val_loss improved from 0.00249 to 0.00239, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 40/50
# 239/239 [==============================] - 2s 7ms/step - loss: 4.1169e-04 - mse: 8.2338e-04 - val_loss: 0.0023 - val_mse: 0.0046
#
# Epoch 00040: val_loss improved from 0.00239 to 0.00230, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 41/50
# 239/239 [==============================] - 2s 6ms/step - loss: 3.9866e-04 - mse: 7.9731e-04 - val_loss: 0.0022 - val_mse: 0.0044
#
# Epoch 00041: val_loss improved from 0.00230 to 0.00220, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 42/50
# 239/239 [==============================] - 1s 5ms/step - loss: 3.8551e-04 - mse: 7.7102e-04 - val_loss: 0.0021 - val_mse: 0.0042
#
# Epoch 00042: val_loss improved from 0.00220 to 0.00211, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 43/50
# 239/239 [==============================] - 1s 6ms/step - loss: 3.7183e-04 - mse: 7.4367e-04 - val_loss: 0.0020 - val_mse: 0.0040
#
# Epoch 00043: val_loss improved from 0.00211 to 0.00198, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 44/50
# 239/239 [==============================] - 1s 5ms/step - loss: 3.5745e-04 - mse: 7.1489e-04 - val_loss: 0.0019 - val_mse: 0.0037
#
# Epoch 00044: val_loss improved from 0.00198 to 0.00187, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 45/50
# 239/239 [==============================] - 2s 6ms/step - loss: 3.4402e-04 - mse: 6.8804e-04 - val_loss: 0.0018 - val_mse: 0.0036
#
# Epoch 00045: val_loss improved from 0.00187 to 0.00180, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 46/50
# 239/239 [==============================] - 1s 6ms/step - loss: 3.3671e-04 - mse: 6.7343e-04 - val_loss: 0.0021 - val_mse: 0.0041
#
# Epoch 00046: val_loss did not improve from 0.00180
# Epoch 47/50
# 239/239 [==============================] - 1s 5ms/step - loss: 3.2470e-04 - mse: 6.4941e-04 - val_loss: 0.0018 - val_mse: 0.0037
#
# Epoch 00047: val_loss did not improve from 0.00180
# Epoch 48/50
# 239/239 [==============================] - 1s 5ms/step - loss: 3.1427e-04 - mse: 6.2854e-04 - val_loss: 0.0016 - val_mse: 0.0032
#
# Epoch 00048: val_loss improved from 0.00180 to 0.00159, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 49/50
# 239/239 [==============================] - 1s 5ms/step - loss: 3.0286e-04 - mse: 6.0572e-04 - val_loss: 0.0015 - val_mse: 0.0030
#
# Epoch 00049: val_loss improved from 0.00159 to 0.00151, saving model to tmp2\Manufacturerckeckpointer.ckpt
# Epoch 50/50
# 239/239 [==============================] - 1s 6ms/step - loss: 2.9329e-04 - mse: 5.8659e-04 - val_loss: 0.0014 - val_mse: 0.0028
#
# Epoch 00050: val_loss improved from 0.00151 to 0.00142, saving model to tmp2\Manufacturerckeckpointer.ckpt

# %%
for sector_name, model in model_dic.items():
    df_일자 = (y_test_dic[sector_name].index)[10::10]
    pred = model.predict(tf_dataset_test_dic[sector_name])
    print(f'{sector_name}의 test_data의 출력 크기 : ' ,pred.shape)
    plt.figure(figsize=(12, 9))
    plt.xlabel(sector_name, fontdict={'size': 20})
    plt.plot(df_일자,np.asarray(y_test_dic[sector_name])[10::10], label='actual')
    plt.plot(df_일자,pred, label='prediction')
    plt.legend()
    plt.show()
# Out:
# 60/60 [==============================] - 0s 2ms/step
# Food의 test_data의 출력 크기 :  (60, 1)
# 60/60 [==============================] - 0s 2ms/step
# Clothing의 test_data의 출력 크기 :  (60, 1)
# 60/60 [==============================] - 0s 2ms/step
# Chemical의 test_data의 출력 크기 :  (60, 1)
# 60/60 [==============================] - 0s 2ms/step
# Medicine의 test_data의 출력 크기 :  (60, 1)
# 60/60 [==============================] - 0s 2ms/step
# Non_Metal의 test_data의 출력 크기 :  (60, 1)
# 60/60 [==============================] - 0s 2ms/step
# Metal의 test_data의 출력 크기 :  (60, 1)
# 60/60 [==============================] - 0s 2ms/step
# Machine의 test_data의 출력 크기 :  (60, 1)
# 60/60 [==============================] - 0s 2ms/step
# Electronic의 test_data의 출력 크기 :  (60, 1)
# 60/60 [==============================] - 0s 2ms/step
# Construction의 test_data의 출력 크기 :  (60, 1)
# 60/60 [==============================] - 0s 2ms/step
# Transport의 test_data의 출력 크기 :  (60, 1)
# 60/60 [==============================] - 0s 2ms/step
# Distribution의 test_data의 출력 크기 :  (60, 1)
# 60/60 [==============================] - 0s 2ms/step
# Power의 test_data의 출력 크기 :  (60, 1)
# 60/60 [==============================] - 0s 2ms/step
# Tele의 test_data의 출력 크기 :  (60, 1)
# 60/60 [==============================] - 0s 2ms/step
# Finance의 test_data의 출력 크기 :  (60, 1)
# 60/60 [==============================] - 0s 2ms/step
# Brokerage의 test_data의 출력 크기 :  (60, 1)
# 60/60 [==============================] - 0s 2ms/step
# Insurer의 test_data의 출력 크기 :  (60, 1)
# 60/60 [==============================] - 0s 2ms/step
# Service의 test_data의 출력 크기 :  (60, 1)
# 60/60 [==============================] - 0s 2ms/step
# Manufacturer의 test_data의 출력 크기 :  (60, 1)

# %% [markdown]
# # today 업종 상향 / 하향 예측하기

# %%
for sector_name, model in model_dic.items():
    pred_l = []
    for i in range(6):
        data = tf.constant(np.expand_dims(np.array(X_test_dic[sector_name].tail(10+i)[:10]),axis=0))
        pred_l.append(float(model.predict(data)))
    pre = sum(pred_l[1:])/5
    if pred_l[0]>pre:
        print(f'{sector_name} 업종은 상향을 예상합니다.')
    elif pred_l[0]<pre:
        print(f'{sector_name} 업종은 하향을 예상합니다.')
# Out:
# Food 업종은 하향을 예상합니다.
# Clothing 업종은 하향을 예상합니다.
# Chemical 업종은 상향을 예상합니다.
# Medicine 업종은 상향을 예상합니다.
# Non_Metal 업종은 상향을 예상합니다.
# Metal 업종은 하향을 예상합니다.
# Machine 업종은 하향을 예상합니다.
# Electronic 업종은 상향을 예상합니다.
# Construction 업종은 하향을 예상합니다.
# Transport 업종은 하향을 예상합니다.
# Distribution 업종은 하향을 예상합니다.
# Power 업종은 하향을 예상합니다.
# Tele 업종은 하향을 예상합니다.
# Finance 업종은 상향을 예상합니다.
# Brokerage 업종은 하향을 예상합니다.
# Insurer 업종은 하향을 예상합니다.
# Service 업종은 하향을 예상합니다.
# Manufacturer 업종은 상향을 예상합니다.

# %%
for sector_name, hist in history_dic.items():    
    plt.plot(hist.history['acc'])
    plt.plot(hist.history['val_acc'])
    plt.title('Accuracy')
    plt.legend(['train','test'], loc='upper left')
    plt.show()
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('Loss')
    plt.legend(['train','test'], loc='upper left')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [63], in <cell line: 1>()
# ----> 1 for sector_name, hist in history_dic.items():
#       2     plt.plot(hist.history['acc'])
#       3     plt.plot(hist.history['val_acc'])
#
# NameError: name 'history_dic' is not defined

# %%
with open('filename_dic.pickle', 'wb') as f:
    pickle.dump(filename_dic,f)

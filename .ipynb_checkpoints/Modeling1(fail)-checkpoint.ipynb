# %% [markdown]
# # 1. 환경 설정

# %%
import pickle
import numpy as np
import pandas as pd
import os
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %%
with open('df_scaled.pickle','rb') as f:
    df_scaled = pickle.load(f)

# %%
df_scaled['Food']
# Out:
#                   종가       등락률     거래변동량  코스피지수_증감량
# 일자
# 2010-05-14  0.074920  0.491660  0.000000   0.511587
# 2010-05-17  0.077067  0.468725  0.025468   0.342590
# 2010-05-18  0.101557  0.554667  0.041343   0.479910
# 2010-05-19  0.087859  0.434181  0.027336   0.461179
# 2010-05-20  0.089447  0.486699  0.028428   0.397058
# ...              ...       ...       ...        ...
# 2022-07-06  0.417075  0.499675  0.023779   0.320948
# 2022-07-07  0.417794  0.515987  0.040026   0.673459
# 2022-07-08  0.410821  0.472507  0.022978   0.574176
# 2022-07-11  0.406615  0.454828  0.016001   0.471981
# 2022-07-12  0.415415  0.495849  0.027874   0.425365
#
# [3000 rows x 4 columns]

# %% [markdown]
# # 2. train / test 분할

# %%
from sklearn.model_selection import train_test_split
X_train_dic = {}
X_test_dic={}
y_train_dic = {}
y_test_dic = {}
#모델이 각 업종마다 존재한다. 18개
for sector_name, df in df_scaled.items():
    # 단 셔플 없이 분할
    X_train, X_test, y_train, y_test = train_test_split(df.drop('종가', 1), df['종가'], test_size=0.2, random_state=0, shuffle=False)
    X_train_dic[sector_name] = X_train
    X_test_dic[sector_name] = X_test
    y_train_dic[sector_name] = y_train
    y_test_dic[sector_name] = y_test

# %%
X_train_dic['Food'].shape, y_train_dic['Food'].shape
# Out:
# ((2400, 3), (2400,))

# %%
X_test_dic['Food'].shape, y_test_dic['Food'].shape
# Out:
# ((600, 3), (600,))

# %%
X_test_dic['Food']
# Out:
#                  등락률     거래변동량  코스피지수_증감량
# 일자
# 2020-02-10  0.486302  0.090778   0.469912
# 2020-02-11  0.582165  0.069031   0.596047
# 2020-02-12  0.623230  0.022802   0.570039
# 2020-02-13  0.510580  0.047191   0.490826
# 2020-02-14  0.470111  0.069654   0.552304
# ...              ...       ...        ...
# 2022-07-06  0.499675  0.023779   0.320948
# 2022-07-07  0.515987  0.040026   0.673459
# 2022-07-08  0.472507  0.022978   0.574176
# 2022-07-11  0.454828  0.016001   0.471981
# 2022-07-12  0.495849  0.027874   0.425365
#
# [600 rows x 3 columns]

# %%
y_test_dic['Food']
# Out:
# 일자
# 2020-02-10    0.142622
# 2020-02-11    0.168579
# 2020-02-12    0.198409
# 2020-02-13    0.207431
# 2020-02-14    0.204221
#                 ...
# 2022-07-06    0.417075
# 2022-07-07    0.417794
# 2022-07-08    0.410821
# 2022-07-11    0.406615
# 2022-07-12    0.415415
# Name: 종가, Length: 600, dtype: float64

# %% [markdown]
# ## feature갯수가 여러개인 경우

# %%
pd.concat([X_train_dic['Food'],y_train_dic['Food']],axis=1).head(10)
# Out:
#                  등락률     거래변동량  코스피지수_증감량        종가
# 일자
# 2010-05-14  0.491660  0.000000   0.511587  0.074920
# 2010-05-17  0.468725  0.025468   0.342590  0.077067
# 2010-05-18  0.554667  0.041343   0.479910  0.101557
# 2010-05-19  0.434181  0.027336   0.461179  0.087859
# 2010-05-20  0.486699  0.028428   0.397058  0.089447
# 2010-05-24  0.469816  0.010051   0.529781  0.085020
# 2010-05-25  0.420716  0.021355   0.342667  0.076165
# 2010-05-26  0.563036  0.007036   0.593136  0.085369
# 2010-05-27  0.508064  0.043104   0.608802  0.084190
# 2010-05-28  0.471144  0.039706   0.570115  0.082391

# %% [markdown]
# # 3. TensorFlow Dataset을 활용한 시퀀스 데이터셋 구성(X데이터, y데이터 각각 구성)
# ## 다중스텝 예측

# %% [markdown]
# ## 예시사진

# %% [markdown]
# <img src="https://blog.kakaocdn.net/dn/yugzK/btrkweR5DyK/kB4xmJOr8GzTAbq614RF1k/img.png" alt="img" style="zoom: 50%;" />

# %%
import tensorflow as tf

# %%
# 윈도우 데이터셋 생성 함수
def windowed_dataset(X, y, X_size, y_size, X_shift, y_shift, X_stride, y_stride, batch_size):
    
    # numpy array x(input)를 Dataset으로 변환
    ds_x = tf.data.Dataset.from_tensor_slices(X)
    
    #윈도우셋 구성
    ds_x = ds_x.window(size=X_size,stride=X_stride, shift=X_shift, drop_remainder=True)
    #한 차원 줄야사 반환
    ds_x = ds_x.flat_map(lambda x: x.batch(X_size))
    
    ds_y = tf.data.Dataset.from_tensor_slices(y)
    ds_y = ds_y.window(size=y_size, stride=y_stride, shift=y_shift, drop_remainder=True)
    ds_y = ds_y.flat_map(lambda y: y.batch(y_size))
    
    #같은 인덱스에 있는 애들 끼리 묶기
    ds = tf.data.Dataset.zip((ds_x, ds_y))
    
    return ds.batch(batch_size).prefetch(1)

# %% [markdown]
# ## Hyperparameter를 정의합니다.

# %%
#윈도우 사이즈
WINDOW_SIZE = 10
# X에 대한 윈도우 함수 설정값
X_size = WINDOW_SIZE
X_shift = 10
X_stride = 1
# y에 대한 윈도우 함수 설정값
y_size = 1
y_shift = WINDOW_SIZE
y_stride = 1

batch_size = 1

tf_dataset_train_dic={}
for sector_name, X_train in X_train_dic.items():
    y_train = y_train_dic[sector_name]
    tf_dataset_train_dic[sector_name] = windowed_dataset(X_train,y_train[WINDOW_SIZE:], X_size, y_size,
                                X_shift, y_shift, X_stride, y_stride, batch_size)

tf_dataset_test_dic = {}
for sector_name, X_test in X_test_dic.items():
    y_test = y_test_dic[sector_name]
    tf_dataset_test_dic[sector_name] = windowed_dataset(X_test,y_test[WINDOW_SIZE:], X_size, y_size,
                                X_shift, y_shift, X_stride, y_stride, batch_size)

    # 데이터 shape, 미리보기로 체크
for x, y in tf_dataset_train_dic['Food'].take(3):
    print('X:', x.shape)
    print(x)
    print()
    print('Y:', y.shape)
    print(y)
    print('-'*100)
# Out:
# X: (1, 10, 3)
# tf.Tensor(
# [[[0.49165988 0.         0.51158693]
#   [0.46872454 0.02546783 0.34259011]
#   [0.55466659 0.04134298 0.4799096 ]
#   [0.43418092 0.027336   0.46117899]
#   [0.48669945 0.02842761 0.39705826]
#   [0.46981555 0.01005135 0.52978128]
#   [0.4207155  0.02135518 0.34266672]
#   [0.5630358  0.00703604 0.59313594]
#   [0.50806373 0.0431039  0.60880224]
#   [0.47114415 0.03970557 0.57011529]]], shape=(1, 10, 3), dtype=float64)
#
# Y: (1, 1)
# tf.Tensor([[0.08930914]], shape=(1, 1), dtype=float64)
# ----------------------------------------------------------------------------------------------------
# X: (1, 10, 3)
# tf.Tensor(
# [[[0.56842294 0.0121771  0.58233424]
#   [0.49388068 0.00575102 0.4700272 ]
#   [0.52007448 0.02070692 0.6320144 ]
#   [0.43344874 0.02260477 0.52035852]
#   [0.45652469 0.01228435 0.41138392]
#   [0.48210753 0.0109208  0.5633355 ]
#   [0.49587358 0.00292051 0.49526947]
#   [0.52859886 0.01082026 0.52874708]
#   [0.53365627 0.01215604 0.60213736]
#   [0.54259766 0.01587706 0.57003869]]], shape=(1, 10, 3), dtype=float64)
#
# Y: (1, 1)
# tf.Tensor([[0.09138455]], shape=(1, 1), dtype=float64)
# ----------------------------------------------------------------------------------------------------
# X: (1, 10, 3)
# tf.Tensor(
# [[[0.47523663 0.01258981 0.50940361]
#   [0.48679157 0.00591763 0.5701919 ]
#   [0.47700163 0.02658912 0.52150764]
#   [0.49653788 0.02809725 0.5270234 ]
#   [0.54197215 0.01680492 0.61780365]
#   [0.46718259 0.01183813 0.48017773]
#   [0.50824314 0.00667601 0.48990692]
#   [0.50244385 0.00467378 0.56540391]
#   [0.51949746 0.01632232 0.47316812]
#   [0.52092304 0.00926712 0.51997549]]], shape=(1, 10, 3), dtype=float64)
#
# Y: (1, 1)
# tf.Tensor([[0.1067426]], shape=(1, 1), dtype=float64)
# ----------------------------------------------------------------------------------------------------

# %%
y_train_dic['Food'][20]
# Out:
# 0.09138454897142578

# %% [markdown]
# ## 모델

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, Lambda
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
model_dic ={}
for sector_name, sector_model in tf_dataset_train_dic.items():
    model_dic[sector_name] = Sequential([
        # 1차원 feature map 생성
        Conv1D(filters=32, kernel_size=5,
               padding="causal",
               activation="relu",
               #feature의 개수 3개
               input_shape=[WINDOW_SIZE, 3]),
        # LSTM
        LSTM(16, activation='tanh'),
        Dense(16, activation="relu"),
        Dense(1),
    ])

# %%
# Sequence 학습에 비교적 좋은 퍼포먼스를 내는 Huber()를 사용합니다.
loss = Huber()
optimizer = Adam(0.0005)
for sector_model in model_dic.values():
    sector_model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])

# %%
# earlystopping은 10번 epoch통안 val_loss 개선이 없다면 학습을 멈춥니다.
earlystopping = EarlyStopping(monitor='val_loss', patience=10)

# val_loss 기준 체크포인터도 생성합니다.
filename_dic={}
for sector_name in tf_dataset_train_dic:
    filename_dic[sector_name] = os.path.join('tmp', sector_name+'ckeckpointer.ckpt')

# %%
#체크포인트를 저장    
mc_dic = {}
for sector_name in filename_dic:
    mc_dic[sector_name] = ModelCheckpoint(filename_dic[sector_name], 
                         save_weights_only=True, 
                         save_best_only=True, 
                         monitor='val_loss', 
                         verbose=1)

# %%
history_dic={}
# 학습+저장
for sector_name, train_data in tf_dataset_train_dic.items():
    test_data = tf_dataset_test_dic[sector_name]
    history = model_dic[sector_name].fit(train_data, 
                        validation_data=(test_data), 
                        epochs=50, 
                        callbacks=[mc_dic[sector_name], earlystopping])
    history_dic[sector_name] = history
# Out:
# Epoch 1/50
# 239/239 [==============================] - 3s 6ms/step - loss: 0.0048 - mse: 0.0096 - val_loss: 0.0446 - val_mse: 0.0893
#
# Epoch 00001: val_loss improved from inf to 0.04463, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0047 - mse: 0.0094 - val_loss: 0.0318 - val_mse: 0.0636
#
# Epoch 00002: val_loss improved from 0.04463 to 0.03178, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 3/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0057 - mse: 0.0113 - val_loss: 0.0225 - val_mse: 0.0451
#
# Epoch 00003: val_loss improved from 0.03178 to 0.02253, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 4/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0065 - mse: 0.0129 - val_loss: 0.0253 - val_mse: 0.0506
#
# Epoch 00004: val_loss did not improve from 0.02253
# Epoch 5/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0063 - mse: 0.0126 - val_loss: 0.0174 - val_mse: 0.0349
#
# Epoch 00005: val_loss improved from 0.02253 to 0.01744, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 6/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0069 - mse: 0.0137 - val_loss: 0.0177 - val_mse: 0.0354
#
# Epoch 00006: val_loss did not improve from 0.01744
# Epoch 7/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0079 - mse: 0.0158 - val_loss: 0.0133 - val_mse: 0.0267
#
# Epoch 00007: val_loss improved from 0.01744 to 0.01334, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 8/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0078 - mse: 0.0156 - val_loss: 0.0208 - val_mse: 0.0416
#
# Epoch 00008: val_loss did not improve from 0.01334
# Epoch 9/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0080 - mse: 0.0160 - val_loss: 0.0131 - val_mse: 0.0262
#
# Epoch 00009: val_loss improved from 0.01334 to 0.01312, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 10/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0094 - mse: 0.0188 - val_loss: 0.0104 - val_mse: 0.0207
#
# Epoch 00010: val_loss improved from 0.01312 to 0.01036, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 11/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0098 - mse: 0.0195 - val_loss: 0.0189 - val_mse: 0.0378
#
# Epoch 00011: val_loss did not improve from 0.01036
# Epoch 12/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0075 - mse: 0.0151 - val_loss: 0.0131 - val_mse: 0.0262
#
# Epoch 00012: val_loss did not improve from 0.01036
# Epoch 13/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0101 - mse: 0.0201 - val_loss: 0.0096 - val_mse: 0.0193
#
# Epoch 00013: val_loss improved from 0.01036 to 0.00965, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 14/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0111 - mse: 0.0221 - val_loss: 0.0092 - val_mse: 0.0184
#
# Epoch 00014: val_loss improved from 0.00965 to 0.00918, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 15/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0128 - mse: 0.0256 - val_loss: 0.0077 - val_mse: 0.0153
#
# Epoch 00015: val_loss improved from 0.00918 to 0.00767, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 16/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0139 - mse: 0.0278 - val_loss: 0.0068 - val_mse: 0.0135
#
# Epoch 00016: val_loss improved from 0.00767 to 0.00675, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 17/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0146 - mse: 0.0292 - val_loss: 0.0062 - val_mse: 0.0124
#
# Epoch 00017: val_loss improved from 0.00675 to 0.00620, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 18/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0129 - mse: 0.0257 - val_loss: 0.0076 - val_mse: 0.0153
#
# Epoch 00018: val_loss did not improve from 0.00620
# Epoch 19/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0146 - mse: 0.0291 - val_loss: 0.0062 - val_mse: 0.0124
#
# Epoch 00019: val_loss did not improve from 0.00620
# Epoch 20/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0153 - mse: 0.0305 - val_loss: 0.0057 - val_mse: 0.0115
#
# Epoch 00020: val_loss improved from 0.00620 to 0.00574, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 21/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0156 - mse: 0.0313 - val_loss: 0.0055 - val_mse: 0.0110
#
# Epoch 00021: val_loss improved from 0.00574 to 0.00552, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 22/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0136 - mse: 0.0272 - val_loss: 0.0066 - val_mse: 0.0133
#
# Epoch 00022: val_loss did not improve from 0.00552
# Epoch 23/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0157 - mse: 0.0315 - val_loss: 0.0057 - val_mse: 0.0113
#
# Epoch 00023: val_loss did not improve from 0.00552
# Epoch 24/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0159 - mse: 0.0319 - val_loss: 0.0054 - val_mse: 0.0107
#
# Epoch 00024: val_loss improved from 0.00552 to 0.00537, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 25/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0161 - mse: 0.0322 - val_loss: 0.0053 - val_mse: 0.0105
#
# Epoch 00025: val_loss improved from 0.00537 to 0.00527, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 26/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0160 - mse: 0.0319 - val_loss: 0.0055 - val_mse: 0.0111
#
# Epoch 00026: val_loss did not improve from 0.00527
# Epoch 27/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0162 - mse: 0.0324 - val_loss: 0.0052 - val_mse: 0.0104
#
# Epoch 00027: val_loss improved from 0.00527 to 0.00521, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 28/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0114 - mse: 0.0228 - val_loss: 0.0427 - val_mse: 0.0854
#
# Epoch 00028: val_loss did not improve from 0.00521
# Epoch 29/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0055 - mse: 0.0109 - val_loss: 0.0190 - val_mse: 0.0380
#
# Epoch 00029: val_loss did not improve from 0.00521
# Epoch 30/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0104 - mse: 0.0208 - val_loss: 0.0062 - val_mse: 0.0124
#
# Epoch 00030: val_loss did not improve from 0.00521
# Epoch 31/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0130 - mse: 0.0259 - val_loss: 0.0481 - val_mse: 0.0961
#
# Epoch 00031: val_loss did not improve from 0.00521
# Epoch 32/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0097 - mse: 0.0195 - val_loss: 0.0057 - val_mse: 0.0115
#
# Epoch 00032: val_loss did not improve from 0.00521
# Epoch 33/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0155 - mse: 0.0310 - val_loss: 0.0052 - val_mse: 0.0105
#
# Epoch 00033: val_loss did not improve from 0.00521
# Epoch 34/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0163 - mse: 0.0326 - val_loss: 0.0051 - val_mse: 0.0103
#
# Epoch 00034: val_loss improved from 0.00521 to 0.00513, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 35/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0165 - mse: 0.0330 - val_loss: 0.0051 - val_mse: 0.0102
#
# Epoch 00035: val_loss improved from 0.00513 to 0.00508, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 36/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0164 - mse: 0.0328 - val_loss: 0.0052 - val_mse: 0.0104
#
# Epoch 00036: val_loss did not improve from 0.00508
# Epoch 37/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0166 - mse: 0.0332 - val_loss: 0.0050 - val_mse: 0.0101
#
# Epoch 00037: val_loss improved from 0.00508 to 0.00505, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 38/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0167 - mse: 0.0334 - val_loss: 0.0050 - val_mse: 0.0101
#
# Epoch 00038: val_loss improved from 0.00505 to 0.00503, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 39/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0167 - mse: 0.0335 - val_loss: 0.0050 - val_mse: 0.0101
#
# Epoch 00039: val_loss did not improve from 0.00503
# Epoch 40/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0165 - mse: 0.0329 - val_loss: 0.0053 - val_mse: 0.0106
#
# Epoch 00040: val_loss did not improve from 0.00503
# Epoch 41/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0167 - mse: 0.0335 - val_loss: 0.0050 - val_mse: 0.0100
#
# Epoch 00041: val_loss improved from 0.00503 to 0.00502, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 42/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0168 - mse: 0.0336 - val_loss: 0.0050 - val_mse: 0.0100
#
# Epoch 00042: val_loss improved from 0.00502 to 0.00502, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 43/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0168 - mse: 0.0337 - val_loss: 0.0050 - val_mse: 0.0100
#
# Epoch 00043: val_loss improved from 0.00502 to 0.00501, saving model to tmp\Foodckeckpointer.ckpt
# Epoch 44/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0139 - mse: 0.0278 - val_loss: 0.0434 - val_mse: 0.0868
#
# Epoch 00044: val_loss did not improve from 0.00501
# Epoch 45/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0056 - mse: 0.0112 - val_loss: 0.0261 - val_mse: 0.0522
#
# Epoch 00045: val_loss did not improve from 0.00501
# Epoch 46/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0054 - mse: 0.0108 - val_loss: 0.0475 - val_mse: 0.0951
#
# Epoch 00046: val_loss did not improve from 0.00501
# Epoch 47/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0055 - mse: 0.0110 - val_loss: 0.0302 - val_mse: 0.0604
#
# Epoch 00047: val_loss did not improve from 0.00501
# Epoch 48/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0069 - mse: 0.0137 - val_loss: 0.0188 - val_mse: 0.0377
#
# Epoch 00048: val_loss did not improve from 0.00501
# Epoch 49/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0087 - mse: 0.0173 - val_loss: 0.0088 - val_mse: 0.0177
#
# Epoch 00049: val_loss did not improve from 0.00501
# Epoch 50/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0131 - mse: 0.0262 - val_loss: 0.0052 - val_mse: 0.0104
#
# Epoch 00050: val_loss did not improve from 0.00501
# Epoch 1/50
# 239/239 [==============================] - 3s 6ms/step - loss: 0.0010 - mse: 0.0020 - val_loss: 0.0992 - val_mse: 0.1983
#
# Epoch 00001: val_loss improved from inf to 0.09915, saving model to tmp\Clothingckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0017 - mse: 0.0033 - val_loss: 0.0834 - val_mse: 0.1668
#
# Epoch 00002: val_loss improved from 0.09915 to 0.08342, saving model to tmp\Clothingckeckpointer.ckpt
# Epoch 3/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0029 - mse: 0.0057 - val_loss: 0.0823 - val_mse: 0.1647
#
# Epoch 00003: val_loss improved from 0.08342 to 0.08233, saving model to tmp\Clothingckeckpointer.ckpt
# Epoch 4/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0020 - mse: 0.0040 - val_loss: 0.0833 - val_mse: 0.1665
#
# Epoch 00004: val_loss did not improve from 0.08233
# Epoch 5/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0029 - mse: 0.0058 - val_loss: 0.0824 - val_mse: 0.1648
#
# Epoch 00005: val_loss did not improve from 0.08233
# Epoch 6/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0038 - mse: 0.0076 - val_loss: 0.0823 - val_mse: 0.1647
#
# Epoch 00006: val_loss did not improve from 0.08233
# Epoch 7/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0042 - mse: 0.0083 - val_loss: 0.0816 - val_mse: 0.1632
#
# Epoch 00007: val_loss improved from 0.08233 to 0.08161, saving model to tmp\Clothingckeckpointer.ckpt
# Epoch 8/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0044 - mse: 0.0088 - val_loss: 0.0808 - val_mse: 0.1617
#
# Epoch 00008: val_loss improved from 0.08161 to 0.08084, saving model to tmp\Clothingckeckpointer.ckpt
# Epoch 9/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0045 - mse: 0.0091 - val_loss: 0.0802 - val_mse: 0.1605
#
# Epoch 00009: val_loss improved from 0.08084 to 0.08025, saving model to tmp\Clothingckeckpointer.ckpt
# Epoch 10/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0047 - mse: 0.0093 - val_loss: 0.0798 - val_mse: 0.1596
#
# Epoch 00010: val_loss improved from 0.08025 to 0.07981, saving model to tmp\Clothingckeckpointer.ckpt
# Epoch 11/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0047 - mse: 0.0094 - val_loss: 0.0795 - val_mse: 0.1591
#
# Epoch 00011: val_loss improved from 0.07981 to 0.07953, saving model to tmp\Clothingckeckpointer.ckpt
# Epoch 12/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0047 - mse: 0.0093 - val_loss: 0.0793 - val_mse: 0.1586
#
# Epoch 00012: val_loss improved from 0.07953 to 0.07931, saving model to tmp\Clothingckeckpointer.ckpt
# Epoch 13/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0047 - mse: 0.0094 - val_loss: 0.0790 - val_mse: 0.1580
#
# Epoch 00013: val_loss improved from 0.07931 to 0.07901, saving model to tmp\Clothingckeckpointer.ckpt
# Epoch 14/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0048 - mse: 0.0096 - val_loss: 0.0789 - val_mse: 0.1578
#
# Epoch 00014: val_loss improved from 0.07901 to 0.07889, saving model to tmp\Clothingckeckpointer.ckpt
# Epoch 15/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0048 - mse: 0.0097 - val_loss: 0.0788 - val_mse: 0.1575
#
# Epoch 00015: val_loss improved from 0.07889 to 0.07877, saving model to tmp\Clothingckeckpointer.ckpt
# Epoch 16/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0049 - mse: 0.0098 - val_loss: 0.0787 - val_mse: 0.1575
#
# Epoch 00016: val_loss improved from 0.07877 to 0.07874, saving model to tmp\Clothingckeckpointer.ckpt
# Epoch 17/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0049 - mse: 0.0097 - val_loss: 0.0786 - val_mse: 0.1572
#
# Epoch 00017: val_loss improved from 0.07874 to 0.07859, saving model to tmp\Clothingckeckpointer.ckpt
# Epoch 18/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0049 - mse: 0.0099 - val_loss: 0.0786 - val_mse: 0.1571
#
# Epoch 00018: val_loss improved from 0.07859 to 0.07857, saving model to tmp\Clothingckeckpointer.ckpt
# Epoch 19/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0049 - mse: 0.0098 - val_loss: 0.0786 - val_mse: 0.1571
#
# Epoch 00019: val_loss improved from 0.07857 to 0.07855, saving model to tmp\Clothingckeckpointer.ckpt
# Epoch 20/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0049 - mse: 0.0098 - val_loss: 0.0785 - val_mse: 0.1570
#
# Epoch 00020: val_loss improved from 0.07855 to 0.07848, saving model to tmp\Clothingckeckpointer.ckpt
# Epoch 21/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0049 - mse: 0.0099 - val_loss: 0.0784 - val_mse: 0.1567
#
# Epoch 00021: val_loss improved from 0.07848 to 0.07836, saving model to tmp\Clothingckeckpointer.ckpt
# Epoch 22/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0051 - mse: 0.0101 - val_loss: 0.0786 - val_mse: 0.1571
#
# Epoch 00022: val_loss did not improve from 0.07836
# Epoch 23/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0050 - mse: 0.0100 - val_loss: 0.0784 - val_mse: 0.1568
#
# Epoch 00023: val_loss did not improve from 0.07836
# Epoch 24/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0048 - mse: 0.0097 - val_loss: 0.0802 - val_mse: 0.1603
#
# Epoch 00024: val_loss did not improve from 0.07836
# Epoch 25/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0048 - mse: 0.0096 - val_loss: 0.0782 - val_mse: 0.1564
#
# Epoch 00025: val_loss improved from 0.07836 to 0.07821, saving model to tmp\Clothingckeckpointer.ckpt
# Epoch 26/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0051 - mse: 0.0102 - val_loss: 0.0785 - val_mse: 0.1571
#
# Epoch 00026: val_loss did not improve from 0.07821
# Epoch 27/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0051 - mse: 0.0102 - val_loss: 0.0786 - val_mse: 0.1571
#
# Epoch 00027: val_loss did not improve from 0.07821
# Epoch 28/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0051 - mse: 0.0102 - val_loss: 0.0786 - val_mse: 0.1572
#
# Epoch 00028: val_loss did not improve from 0.07821
# Epoch 29/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0051 - mse: 0.0102 - val_loss: 0.0787 - val_mse: 0.1573
#
# Epoch 00029: val_loss did not improve from 0.07821
# Epoch 30/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0051 - mse: 0.0103 - val_loss: 0.0788 - val_mse: 0.1576
#
# Epoch 00030: val_loss did not improve from 0.07821
# Epoch 31/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0050 - mse: 0.0100 - val_loss: 0.0784 - val_mse: 0.1569
#
# Epoch 00031: val_loss did not improve from 0.07821
# Epoch 32/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0051 - mse: 0.0102 - val_loss: 0.0785 - val_mse: 0.1571
#
# Epoch 00032: val_loss did not improve from 0.07821
# Epoch 33/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0051 - mse: 0.0103 - val_loss: 0.0787 - val_mse: 0.1574
#
# Epoch 00033: val_loss did not improve from 0.07821
# Epoch 34/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0051 - mse: 0.0102 - val_loss: 0.0787 - val_mse: 0.1573
#
# Epoch 00034: val_loss did not improve from 0.07821
# Epoch 35/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0051 - mse: 0.0102 - val_loss: 0.0787 - val_mse: 0.1575
#
# Epoch 00035: val_loss did not improve from 0.07821
# Epoch 1/50
# 239/239 [==============================] - 3s 6ms/step - loss: 0.0015 - mse: 0.0030 - val_loss: 0.0389 - val_mse: 0.0779
#
# Epoch 00001: val_loss improved from inf to 0.03893, saving model to tmp\Chemicalckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mse: 0.0082 - val_loss: 0.0336 - val_mse: 0.0672
#
# Epoch 00002: val_loss improved from 0.03893 to 0.03359, saving model to tmp\Chemicalckeckpointer.ckpt
# Epoch 3/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0065 - mse: 0.0130 - val_loss: 0.0357 - val_mse: 0.0714
#
# Epoch 00003: val_loss did not improve from 0.03359
# Epoch 4/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0066 - mse: 0.0132 - val_loss: 0.0323 - val_mse: 0.0646
#
# Epoch 00004: val_loss improved from 0.03359 to 0.03228, saving model to tmp\Chemicalckeckpointer.ckpt
# Epoch 5/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0069 - mse: 0.0139 - val_loss: 0.0321 - val_mse: 0.0642
#
# Epoch 00005: val_loss improved from 0.03228 to 0.03211, saving model to tmp\Chemicalckeckpointer.ckpt
# Epoch 6/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0072 - mse: 0.0144 - val_loss: 0.0309 - val_mse: 0.0617
#
# Epoch 00006: val_loss improved from 0.03211 to 0.03086, saving model to tmp\Chemicalckeckpointer.ckpt
# Epoch 7/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0097 - mse: 0.0193 - val_loss: 0.0380 - val_mse: 0.0759
#
# Epoch 00007: val_loss did not improve from 0.03086
# Epoch 8/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0094 - mse: 0.0188 - val_loss: 0.0310 - val_mse: 0.0621
#
# Epoch 00008: val_loss did not improve from 0.03086
# Epoch 9/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0122 - mse: 0.0244 - val_loss: 0.0335 - val_mse: 0.0670
#
# Epoch 00009: val_loss did not improve from 0.03086
# Epoch 10/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0128 - mse: 0.0257 - val_loss: 0.0323 - val_mse: 0.0647
#
# Epoch 00010: val_loss did not improve from 0.03086
# Epoch 11/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0137 - mse: 0.0274 - val_loss: 0.0394 - val_mse: 0.0789
#
# Epoch 00011: val_loss did not improve from 0.03086
# Epoch 12/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0142 - mse: 0.0285 - val_loss: 0.0424 - val_mse: 0.0848
#
# Epoch 00012: val_loss did not improve from 0.03086
# Epoch 13/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0145 - mse: 0.0290 - val_loss: 0.0447 - val_mse: 0.0894
#
# Epoch 00013: val_loss did not improve from 0.03086
# Epoch 14/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0133 - mse: 0.0267 - val_loss: 0.0331 - val_mse: 0.0662
#
# Epoch 00014: val_loss did not improve from 0.03086
# Epoch 15/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0137 - mse: 0.0274 - val_loss: 0.0440 - val_mse: 0.0879
#
# Epoch 00015: val_loss did not improve from 0.03086
# Epoch 16/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0132 - mse: 0.0263 - val_loss: 0.0320 - val_mse: 0.0641
#
# Epoch 00016: val_loss did not improve from 0.03086
# Epoch 1/50
# 239/239 [==============================] - 3s 6ms/step - loss: 0.0028 - mse: 0.0056 - val_loss: 0.0573 - val_mse: 0.1146
#
# Epoch 00001: val_loss improved from inf to 0.05732, saving model to tmp\Medicineckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0110 - mse: 0.0220 - val_loss: 0.0507 - val_mse: 0.1015
#
# Epoch 00002: val_loss improved from 0.05732 to 0.05073, saving model to tmp\Medicineckeckpointer.ckpt
# Epoch 3/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0127 - mse: 0.0253 - val_loss: 0.0354 - val_mse: 0.0709
#
# Epoch 00003: val_loss improved from 0.05073 to 0.03544, saving model to tmp\Medicineckeckpointer.ckpt
# Epoch 4/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0224 - mse: 0.0447 - val_loss: 0.0279 - val_mse: 0.0557
#
# Epoch 00004: val_loss improved from 0.03544 to 0.02785, saving model to tmp\Medicineckeckpointer.ckpt
# Epoch 5/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0203 - mse: 0.0406 - val_loss: 0.0442 - val_mse: 0.0884
#
# Epoch 00005: val_loss did not improve from 0.02785
# Epoch 6/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0215 - mse: 0.0429 - val_loss: 0.0289 - val_mse: 0.0578
#
# Epoch 00006: val_loss did not improve from 0.02785
# Epoch 7/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0296 - mse: 0.0591 - val_loss: 0.0492 - val_mse: 0.0984
#
# Epoch 00007: val_loss did not improve from 0.02785
# Epoch 8/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0308 - mse: 0.0617 - val_loss: 0.0606 - val_mse: 0.1211
#
# Epoch 00008: val_loss did not improve from 0.02785
# Epoch 9/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0307 - mse: 0.0614 - val_loss: 0.0670 - val_mse: 0.1339
#
# Epoch 00009: val_loss did not improve from 0.02785
# Epoch 10/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0306 - mse: 0.0611 - val_loss: 0.0714 - val_mse: 0.1427
#
# Epoch 00010: val_loss did not improve from 0.02785
# Epoch 11/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0305 - mse: 0.0609 - val_loss: 0.0744 - val_mse: 0.1487
#
# Epoch 00011: val_loss did not improve from 0.02785
# Epoch 12/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0304 - mse: 0.0607 - val_loss: 0.0764 - val_mse: 0.1528
#
# Epoch 00012: val_loss did not improve from 0.02785
# Epoch 13/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0299 - mse: 0.0598 - val_loss: 0.0756 - val_mse: 0.1512
#
# Epoch 00013: val_loss did not improve from 0.02785
# Epoch 14/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0304 - mse: 0.0609 - val_loss: 0.0785 - val_mse: 0.1571
#
# Epoch 00014: val_loss did not improve from 0.02785
# Epoch 1/50
# 239/239 [==============================] - 3s 6ms/step - loss: 7.1622e-04 - mse: 0.0014 - val_loss: 0.1076 - val_mse: 0.2151
#
# Epoch 00001: val_loss improved from inf to 0.10757, saving model to tmp\Non_Metalckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0028 - mse: 0.0057 - val_loss: 0.0866 - val_mse: 0.1733
#
# Epoch 00002: val_loss improved from 0.10757 to 0.08663, saving model to tmp\Non_Metalckeckpointer.ckpt
# Epoch 3/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0052 - mse: 0.0104 - val_loss: 0.0777 - val_mse: 0.1555
#
# Epoch 00003: val_loss improved from 0.08663 to 0.07773, saving model to tmp\Non_Metalckeckpointer.ckpt
# Epoch 4/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0069 - mse: 0.0138 - val_loss: 0.0786 - val_mse: 0.1572
#
# Epoch 00004: val_loss did not improve from 0.07773
# Epoch 5/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0078 - mse: 0.0155 - val_loss: 0.0948 - val_mse: 0.1895
#
# Epoch 00005: val_loss did not improve from 0.07773
# Epoch 6/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0032 - mse: 0.0064 - val_loss: 0.0794 - val_mse: 0.1587
#
# Epoch 00006: val_loss did not improve from 0.07773
# Epoch 7/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0047 - mse: 0.0094 - val_loss: 0.0793 - val_mse: 0.1586
#
# Epoch 00007: val_loss did not improve from 0.07773
# Epoch 8/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0055 - mse: 0.0111 - val_loss: 0.0838 - val_mse: 0.1676
#
# Epoch 00008: val_loss did not improve from 0.07773
# Epoch 9/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0087 - mse: 0.0174 - val_loss: 0.0801 - val_mse: 0.1602
#
# Epoch 00009: val_loss did not improve from 0.07773
# Epoch 10/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0089 - mse: 0.0178 - val_loss: 0.0915 - val_mse: 0.1830
#
# Epoch 00010: val_loss did not improve from 0.07773
# Epoch 11/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0091 - mse: 0.0182 - val_loss: 0.0955 - val_mse: 0.1911
#
# Epoch 00011: val_loss did not improve from 0.07773
# Epoch 12/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0091 - mse: 0.0183 - val_loss: 0.0976 - val_mse: 0.1952
#
# Epoch 00012: val_loss did not improve from 0.07773
# Epoch 13/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0066 - mse: 0.0132 - val_loss: 0.0794 - val_mse: 0.1589
#
# Epoch 00013: val_loss did not improve from 0.07773
# Epoch 1/50
# 239/239 [==============================] - 3s 6ms/step - loss: 0.0104 - mse: 0.0209 - val_loss: 0.0082 - val_mse: 0.0165
#
# Epoch 00001: val_loss improved from inf to 0.00824, saving model to tmp\Metalckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0112 - mse: 0.0224 - val_loss: 0.0073 - val_mse: 0.0146
#
# Epoch 00002: val_loss improved from 0.00824 to 0.00728, saving model to tmp\Metalckeckpointer.ckpt
# Epoch 3/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0136 - mse: 0.0271 - val_loss: 0.0067 - val_mse: 0.0133
#
# Epoch 00003: val_loss improved from 0.00728 to 0.00666, saving model to tmp\Metalckeckpointer.ckpt
# Epoch 4/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0146 - mse: 0.0293 - val_loss: 0.0067 - val_mse: 0.0134
#
# Epoch 00004: val_loss did not improve from 0.00666
# Epoch 5/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0161 - mse: 0.0323 - val_loss: 0.0069 - val_mse: 0.0138
#
# Epoch 00005: val_loss did not improve from 0.00666
# Epoch 6/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0169 - mse: 0.0339 - val_loss: 0.0069 - val_mse: 0.0138
#
# Epoch 00006: val_loss did not improve from 0.00666
# Epoch 7/50
# 239/239 [==============================] - ETA: 0s - loss: 0.0175 - mse: 0.035 - 1s 4ms/step - loss: 0.0173 - mse: 0.0346 - val_loss: 0.0069 - val_mse: 0.0139
#
# Epoch 00007: val_loss did not improve from 0.00666
# Epoch 8/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0176 - mse: 0.0353 - val_loss: 0.0068 - val_mse: 0.0135
#
# Epoch 00008: val_loss did not improve from 0.00666
# Epoch 9/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0169 - mse: 0.0339 - val_loss: 0.0069 - val_mse: 0.0139
#
# Epoch 00009: val_loss did not improve from 0.00666
# Epoch 10/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0169 - mse: 0.0338 - val_loss: 0.0070 - val_mse: 0.0140
#
# Epoch 00010: val_loss did not improve from 0.00666
# Epoch 11/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0181 - mse: 0.0362 - val_loss: 0.0073 - val_mse: 0.0145
#
# Epoch 00011: val_loss did not improve from 0.00666
# Epoch 12/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0187 - mse: 0.0373 - val_loss: 0.0074 - val_mse: 0.0148
#
# Epoch 00012: val_loss did not improve from 0.00666
# Epoch 13/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0189 - mse: 0.0377 - val_loss: 0.0075 - val_mse: 0.0149
#
# Epoch 00013: val_loss did not improve from 0.00666
# Epoch 1/50
# 239/239 [==============================] - 3s 6ms/step - loss: 0.0037 - mse: 0.0073 - val_loss: 0.0954 - val_mse: 0.1909
#
# Epoch 00001: val_loss improved from inf to 0.09543, saving model to tmp\Machineckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0059 - mse: 0.0117 - val_loss: 0.0966 - val_mse: 0.1933
#
# Epoch 00002: val_loss did not improve from 0.09543
# Epoch 3/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0067 - mse: 0.0134 - val_loss: 0.0967 - val_mse: 0.1934
#
# Epoch 00003: val_loss did not improve from 0.09543
# Epoch 4/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0067 - mse: 0.0134 - val_loss: 0.0946 - val_mse: 0.1892
#
# Epoch 00004: val_loss improved from 0.09543 to 0.09461, saving model to tmp\Machineckeckpointer.ckpt
# Epoch 5/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0073 - mse: 0.0146 - val_loss: 0.0918 - val_mse: 0.1835
#
# Epoch 00005: val_loss improved from 0.09461 to 0.09176, saving model to tmp\Machineckeckpointer.ckpt
# Epoch 6/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0077 - mse: 0.0154 - val_loss: 0.0918 - val_mse: 0.1836
#
# Epoch 00006: val_loss did not improve from 0.09176
# Epoch 7/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0081 - mse: 0.0163 - val_loss: 0.0912 - val_mse: 0.1823
#
# Epoch 00007: val_loss improved from 0.09176 to 0.09117, saving model to tmp\Machineckeckpointer.ckpt
# Epoch 8/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0077 - mse: 0.0155 - val_loss: 0.0961 - val_mse: 0.1923
#
# Epoch 00008: val_loss did not improve from 0.09117
# Epoch 9/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0069 - mse: 0.0139 - val_loss: 0.0927 - val_mse: 0.1854
#
# Epoch 00009: val_loss did not improve from 0.09117
# Epoch 10/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0072 - mse: 0.0143 - val_loss: 0.0952 - val_mse: 0.1905
#
# Epoch 00010: val_loss did not improve from 0.09117
# Epoch 11/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0063 - mse: 0.0126 - val_loss: 0.0979 - val_mse: 0.1958
#
# Epoch 00011: val_loss did not improve from 0.09117
# Epoch 12/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0070 - mse: 0.0139 - val_loss: 0.0941 - val_mse: 0.1883
#
# Epoch 00012: val_loss did not improve from 0.09117
# Epoch 13/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0062 - mse: 0.0123 - val_loss: 0.0974 - val_mse: 0.1948
#
# Epoch 00013: val_loss did not improve from 0.09117
# Epoch 14/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0073 - mse: 0.0146 - val_loss: 0.0908 - val_mse: 0.1815
#
# Epoch 00014: val_loss improved from 0.09117 to 0.09077, saving model to tmp\Machineckeckpointer.ckpt
# Epoch 15/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0083 - mse: 0.0167 - val_loss: 0.0920 - val_mse: 0.1840
#
# Epoch 00015: val_loss did not improve from 0.09077
# Epoch 16/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0083 - mse: 0.0166 - val_loss: 0.0918 - val_mse: 0.1836
#
# Epoch 00016: val_loss did not improve from 0.09077
# Epoch 17/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0065 - mse: 0.0130 - val_loss: 0.0985 - val_mse: 0.1971
#
# Epoch 00017: val_loss did not improve from 0.09077
# Epoch 18/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0064 - mse: 0.0128 - val_loss: 0.0920 - val_mse: 0.1840
#
# Epoch 00018: val_loss did not improve from 0.09077
# Epoch 19/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0090 - mse: 0.0181 - val_loss: 0.0949 - val_mse: 0.1897
#
# Epoch 00019: val_loss did not improve from 0.09077
# Epoch 20/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0103 - mse: 0.0207 - val_loss: 0.0957 - val_mse: 0.1914
#
# Epoch 00020: val_loss did not improve from 0.09077
# Epoch 21/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0110 - mse: 0.0220 - val_loss: 0.0954 - val_mse: 0.1908
#
# Epoch 00021: val_loss did not improve from 0.09077
# Epoch 22/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0114 - mse: 0.0227 - val_loss: 0.0950 - val_mse: 0.1900
#
# Epoch 00022: val_loss did not improve from 0.09077
# Epoch 23/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0116 - mse: 0.0232 - val_loss: 0.0945 - val_mse: 0.1891
#
# Epoch 00023: val_loss did not improve from 0.09077
# Epoch 24/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0117 - mse: 0.0235 - val_loss: 0.0927 - val_mse: 0.1853
#
# Epoch 00024: val_loss did not improve from 0.09077
# Epoch 1/50
# 239/239 [==============================] - 3s 6ms/step - loss: 5.0307e-04 - mse: 0.0010 - val_loss: 0.1151 - val_mse: 0.2302
#
# Epoch 00001: val_loss improved from inf to 0.11508, saving model to tmp\Electronicckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0011 - mse: 0.0022 - val_loss: 0.1142 - val_mse: 0.2284
#
# Epoch 00002: val_loss improved from 0.11508 to 0.11420, saving model to tmp\Electronicckeckpointer.ckpt
# Epoch 3/50
# 239/239 [==============================] - 1s 5ms/step - loss: 9.5403e-04 - mse: 0.0019 - val_loss: 0.1262 - val_mse: 0.2524
#
# Epoch 00003: val_loss did not improve from 0.11420
# Epoch 4/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0010 - mse: 0.0021 - val_loss: 0.1258 - val_mse: 0.2516
#
# Epoch 00004: val_loss did not improve from 0.11420
# Epoch 5/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0011 - mse: 0.0023 - val_loss: 0.1162 - val_mse: 0.2323
#
# Epoch 00005: val_loss did not improve from 0.11420
# Epoch 6/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0013 - mse: 0.0026 - val_loss: 0.1258 - val_mse: 0.2516
#
# Epoch 00006: val_loss did not improve from 0.11420
# Epoch 7/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0015 - mse: 0.0031 - val_loss: 0.1229 - val_mse: 0.2457
#
# Epoch 00007: val_loss did not improve from 0.11420
# Epoch 8/50
# 239/239 [==============================] - 1s 4ms/step - loss: 7.9136e-04 - mse: 0.0016 - val_loss: 0.1165 - val_mse: 0.2329
#
# Epoch 00008: val_loss did not improve from 0.11420
# Epoch 9/50
# 239/239 [==============================] - 1s 4ms/step - loss: 8.8431e-04 - mse: 0.0018 - val_loss: 0.1237 - val_mse: 0.2474
#
# Epoch 00009: val_loss did not improve from 0.11420
# Epoch 10/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0011 - mse: 0.0022 - val_loss: 0.1281 - val_mse: 0.2562
#
# Epoch 00010: val_loss did not improve from 0.11420
# Epoch 11/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0017 - mse: 0.0034 - val_loss: 0.1226 - val_mse: 0.2452
#
# Epoch 00011: val_loss did not improve from 0.11420
# Epoch 12/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0019 - mse: 0.0038 - val_loss: 0.1250 - val_mse: 0.2500
#
# Epoch 00012: val_loss did not improve from 0.11420
# Epoch 1/50
# 239/239 [==============================] - 3s 6ms/step - loss: 0.0090 - mse: 0.0180 - val_loss: 0.0059 - val_mse: 0.0118
#
# Epoch 00001: val_loss improved from inf to 0.00592, saving model to tmp\Constructionckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0092 - mse: 0.0183 - val_loss: 0.0055 - val_mse: 0.0109
#
# Epoch 00002: val_loss improved from 0.00592 to 0.00546, saving model to tmp\Constructionckeckpointer.ckpt
# Epoch 3/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0100 - mse: 0.0199 - val_loss: 0.0059 - val_mse: 0.0118
#
# Epoch 00003: val_loss did not improve from 0.00546
# Epoch 4/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0110 - mse: 0.0219 - val_loss: 0.0067 - val_mse: 0.0135
#
# Epoch 00004: val_loss did not improve from 0.00546
# Epoch 5/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0124 - mse: 0.0249 - val_loss: 0.0069 - val_mse: 0.0139
#
# Epoch 00005: val_loss did not improve from 0.00546
# Epoch 6/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0141 - mse: 0.0282 - val_loss: 0.0073 - val_mse: 0.0147
#
# Epoch 00006: val_loss did not improve from 0.00546
# Epoch 7/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0148 - mse: 0.0297 - val_loss: 0.0077 - val_mse: 0.0154
#
# Epoch 00007: val_loss did not improve from 0.00546
# Epoch 8/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0153 - mse: 0.0305 - val_loss: 0.0081 - val_mse: 0.0161
#
# Epoch 00008: val_loss did not improve from 0.00546
# Epoch 9/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0155 - mse: 0.0311 - val_loss: 0.0084 - val_mse: 0.0168
#
# Epoch 00009: val_loss did not improve from 0.00546
# Epoch 10/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0157 - mse: 0.0315 - val_loss: 0.0087 - val_mse: 0.0174
#
# Epoch 00010: val_loss did not improve from 0.00546
# Epoch 11/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0159 - mse: 0.0318 - val_loss: 0.0090 - val_mse: 0.0179
#
# Epoch 00011: val_loss did not improve from 0.00546
# Epoch 12/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0160 - mse: 0.0319 - val_loss: 0.0092 - val_mse: 0.0185
#
# Epoch 00012: val_loss did not improve from 0.00546
# Epoch 1/50
# 239/239 [==============================] - 3s 6ms/step - loss: 0.0065 - mse: 0.0131 - val_loss: 0.0043 - val_mse: 0.0086
#
# Epoch 00001: val_loss improved from inf to 0.00428, saving model to tmp\Transportckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0134 - mse: 0.0267 - val_loss: 0.0067 - val_mse: 0.0134
#
# Epoch 00002: val_loss did not improve from 0.00428
# Epoch 3/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0241 - mse: 0.0482 - val_loss: 0.0046 - val_mse: 0.0093
#
# Epoch 00003: val_loss did not improve from 0.00428
# Epoch 4/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0277 - mse: 0.0554 - val_loss: 0.0040 - val_mse: 0.0080
#
# Epoch 00004: val_loss improved from 0.00428 to 0.00402, saving model to tmp\Transportckeckpointer.ckpt
# Epoch 5/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0317 - mse: 0.0634 - val_loss: 0.0030 - val_mse: 0.0060
#
# Epoch 00005: val_loss improved from 0.00402 to 0.00301, saving model to tmp\Transportckeckpointer.ckpt
# Epoch 6/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0331 - mse: 0.0662 - val_loss: 0.0026 - val_mse: 0.0052
#
# Epoch 00006: val_loss improved from 0.00301 to 0.00261, saving model to tmp\Transportckeckpointer.ckpt
# Epoch 7/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0337 - mse: 0.0674 - val_loss: 0.0028 - val_mse: 0.0055
#
# Epoch 00007: val_loss did not improve from 0.00261
# Epoch 8/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0340 - mse: 0.0681 - val_loss: 0.0021 - val_mse: 0.0042
#
# Epoch 00008: val_loss improved from 0.00261 to 0.00211, saving model to tmp\Transportckeckpointer.ckpt
# Epoch 9/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0342 - mse: 0.0683 - val_loss: 0.0020 - val_mse: 0.0040
#
# Epoch 00009: val_loss improved from 0.00211 to 0.00202, saving model to tmp\Transportckeckpointer.ckpt
# Epoch 10/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0338 - mse: 0.0677 - val_loss: 0.0045 - val_mse: 0.0090
#
# Epoch 00010: val_loss did not improve from 0.00202
# Epoch 11/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0297 - mse: 0.0595 - val_loss: 0.0026 - val_mse: 0.0052
#
# Epoch 00011: val_loss did not improve from 0.00202
# Epoch 12/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0347 - mse: 0.0694 - val_loss: 0.0026 - val_mse: 0.0051
#
# Epoch 00012: val_loss did not improve from 0.00202
# Epoch 13/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0345 - mse: 0.0691 - val_loss: 0.0019 - val_mse: 0.0039
# Epoch 00013: val_loss improved from 0.00202 to 0.00194, saving model to tmp\Transportckeckpointer.ckpt
# Epoch 14/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0336 - mse: 0.0672 - val_loss: 0.0027 - val_mse: 0.0055
#
# Epoch 00014: val_loss did not improve from 0.00194
# Epoch 15/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0339 - mse: 0.0677 - val_loss: 0.0041 - val_mse: 0.0083
#
# Epoch 00015: val_loss did not improve from 0.00194
# Epoch 16/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0338 - mse: 0.0677 - val_loss: 0.0097 - val_mse: 0.0194
#
# Epoch 00016: val_loss did not improve from 0.00194
# Epoch 17/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0226 - mse: 0.0451 - val_loss: 0.0024 - val_mse: 0.0048
#
# Epoch 00017: val_loss did not improve from 0.00194
# Epoch 18/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0358 - mse: 0.0715 - val_loss: 0.0017 - val_mse: 0.0034
#
# Epoch 00018: val_loss improved from 0.00194 to 0.00170, saving model to tmp\Transportckeckpointer.ckpt
# Epoch 19/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0339 - mse: 0.0679 - val_loss: 0.0020 - val_mse: 0.0040
#
# Epoch 00019: val_loss did not improve from 0.00170
# Epoch 20/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0344 - mse: 0.0688 - val_loss: 0.0019 - val_mse: 0.0038
#
# Epoch 00020: val_loss did not improve from 0.00170
# Epoch 21/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0332 - mse: 0.0664 - val_loss: 0.0099 - val_mse: 0.0198
#
# Epoch 00021: val_loss did not improve from 0.00170
# Epoch 22/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0345 - mse: 0.0689 - val_loss: 0.0035 - val_mse: 0.0070
#
# Epoch 00022: val_loss did not improve from 0.00170
# Epoch 23/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0333 - mse: 0.0667 - val_loss: 0.0172 - val_mse: 0.0344
#
# Epoch 00023: val_loss did not improve from 0.00170
# Epoch 24/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0340 - mse: 0.0679 - val_loss: 0.0035 - val_mse: 0.0071
#
# Epoch 00024: val_loss did not improve from 0.00170
# Epoch 25/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0333 - mse: 0.0666 - val_loss: 0.0063 - val_mse: 0.0125
#
# Epoch 00025: val_loss did not improve from 0.00170
# Epoch 26/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0335 - mse: 0.0671 - val_loss: 0.0066 - val_mse: 0.0132
#
# Epoch 00026: val_loss did not improve from 0.00170
# Epoch 27/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0320 - mse: 0.0639 - val_loss: 0.0122 - val_mse: 0.0243
#
# Epoch 00027: val_loss did not improve from 0.00170
# Epoch 28/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0188 - mse: 0.0376 - val_loss: 0.0034 - val_mse: 0.0067
#
# Epoch 00028: val_loss did not improve from 0.00170
# Epoch 1/50
# 239/239 [==============================] - 3s 6ms/step - loss: 0.0122 - mse: 0.0243 - val_loss: 0.0023 - val_mse: 0.0046
#
# Epoch 00001: val_loss improved from inf to 0.00229, saving model to tmp\Distributionckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0161 - mse: 0.0321 - val_loss: 0.0117 - val_mse: 0.0234
#
# Epoch 00002: val_loss did not improve from 0.00229
# Epoch 3/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0184 - mse: 0.0367 - val_loss: 0.0136 - val_mse: 0.0273
#
# Epoch 00003: val_loss did not improve from 0.00229
# Epoch 4/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0193 - mse: 0.0385 - val_loss: 0.0147 - val_mse: 0.0294
#
# Epoch 00004: val_loss did not improve from 0.00229
# Epoch 5/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0200 - mse: 0.0400 - val_loss: 0.0156 - val_mse: 0.0313
#
# Epoch 00005: val_loss did not improve from 0.00229
# Epoch 6/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0205 - mse: 0.0410 - val_loss: 0.0165 - val_mse: 0.0330
#
# Epoch 00006: val_loss did not improve from 0.00229
# Epoch 7/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0209 - mse: 0.0418 - val_loss: 0.0173 - val_mse: 0.0346
#
# Epoch 00007: val_loss did not improve from 0.00229
# Epoch 8/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0211 - mse: 0.0423 - val_loss: 0.0179 - val_mse: 0.0358
#
# Epoch 00008: val_loss did not improve from 0.00229
# Epoch 9/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0213 - mse: 0.0427 - val_loss: 0.0184 - val_mse: 0.0368
#
# Epoch 00009: val_loss did not improve from 0.00229
# Epoch 10/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0207 - mse: 0.0414 - val_loss: 0.0141 - val_mse: 0.0283
#
# Epoch 00010: val_loss did not improve from 0.00229
# Epoch 11/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0198 - mse: 0.0396 - val_loss: 0.0167 - val_mse: 0.0335
#
# Epoch 00011: val_loss did not improve from 0.00229
# Epoch 1/50
# 239/239 [==============================] - 3s 6ms/step - loss: 0.0034 - mse: 0.0069 - val_loss: 0.0496 - val_mse: 0.0992
#
# Epoch 00001: val_loss improved from inf to 0.04959, saving model to tmp\Powerckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0051 - mse: 0.0102 - val_loss: 0.0415 - val_mse: 0.0830
#
# Epoch 00002: val_loss improved from 0.04959 to 0.04148, saving model to tmp\Powerckeckpointer.ckpt
# Epoch 3/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0124 - mse: 0.0249 - val_loss: 0.0381 - val_mse: 0.0762
#
# Epoch 00003: val_loss improved from 0.04148 to 0.03810, saving model to tmp\Powerckeckpointer.ckpt
# Epoch 4/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0165 - mse: 0.0330 - val_loss: 0.0368 - val_mse: 0.0737
#
# Epoch 00004: val_loss improved from 0.03810 to 0.03684, saving model to tmp\Powerckeckpointer.ckpt
# Epoch 5/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0180 - mse: 0.0359 - val_loss: 0.0361 - val_mse: 0.0722
#
# Epoch 00005: val_loss improved from 0.03684 to 0.03609, saving model to tmp\Powerckeckpointer.ckpt
# Epoch 6/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0187 - mse: 0.0373 - val_loss: 0.0356 - val_mse: 0.0713
#
# Epoch 00006: val_loss improved from 0.03609 to 0.03565, saving model to tmp\Powerckeckpointer.ckpt
# Epoch 7/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0191 - mse: 0.0381 - val_loss: 0.0354 - val_mse: 0.0708
#
# Epoch 00007: val_loss improved from 0.03565 to 0.03538, saving model to tmp\Powerckeckpointer.ckpt
# Epoch 8/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0193 - mse: 0.0386 - val_loss: 0.0352 - val_mse: 0.0704
#
# Epoch 00008: val_loss improved from 0.03538 to 0.03521, saving model to tmp\Powerckeckpointer.ckpt
# Epoch 9/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0188 - mse: 0.0376 - val_loss: 0.0356 - val_mse: 0.0713
#
# Epoch 00009: val_loss did not improve from 0.03521
# Epoch 10/50
# ...
#
# Epoch 00007: val_loss did not improve from 0.02816
# Epoch 8/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0111 - mse: 0.0221 - val_loss: 0.0283 - val_mse: 0.0566
#
# Epoch 00008: val_loss did not improve from 0.02816
# Epoch 9/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0112 - mse: 0.0224 - val_loss: 0.0284 - val_mse: 0.0568
#
# Epoch 00009: val_loss did not improve from 0.02816
# Epoch 10/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0113 - mse: 0.0225 - val_loss: 0.0285 - val_mse: 0.0571
#
# Epoch 00010: val_loss did not improve from 0.02816
# Epoch 11/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0113 - mse: 0.0225 - val_loss: 0.0285 - val_mse: 0.0570
#
# Epoch 00011: val_loss did not improve from 0.02816
# Epoch 12/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0113 - mse: 0.0227 - val_loss: 0.0286 - val_mse: 0.0572
#
# Epoch 00012: val_loss did not improve from 0.02816
# Epoch 13/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0114 - mse: 0.0227 - val_loss: 0.0288 - val_mse: 0.0575
#
# Epoch 00013: val_loss did not improve from 0.02816
# Epoch 14/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0114 - mse: 0.0228 - val_loss: 0.0287 - val_mse: 0.0574
#
# Epoch 00014: val_loss did not improve from 0.02816
# Epoch 15/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0113 - mse: 0.0227 - val_loss: 0.0287 - val_mse: 0.0574
#
# Epoch 00015: val_loss did not improve from 0.02816
# Epoch 1/50
# 239/239 [==============================] - 3s 6ms/step - loss: 0.0076 - mse: 0.0153 - val_loss: 0.0219 - val_mse: 0.0437
#
# Epoch 00001: val_loss improved from inf to 0.02187, saving model to tmp\Financeckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0055 - mse: 0.0110 - val_loss: 0.0277 - val_mse: 0.0554
#
# Epoch 00002: val_loss did not improve from 0.02187
# Epoch 3/50
# 239/239 [==============================] - 1s 6ms/step - loss: 0.0055 - mse: 0.0110 - val_loss: 0.0315 - val_mse: 0.0629
#
# Epoch 00003: val_loss did not improve from 0.02187
# Epoch 4/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0057 - mse: 0.0113 - val_loss: 0.0345 - val_mse: 0.0689
#
# Epoch 00004: val_loss did not improve from 0.02187
# Epoch 5/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0059 - mse: 0.0118 - val_loss: 0.0367 - val_mse: 0.0734
#
# Epoch 00005: val_loss did not improve from 0.02187
# Epoch 6/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0061 - mse: 0.0123 - val_loss: 0.0384 - val_mse: 0.0767
#
# Epoch 00006: val_loss did not improve from 0.02187
# Epoch 7/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0064 - mse: 0.0127 - val_loss: 0.0396 - val_mse: 0.0792
#
# Epoch 00007: val_loss did not improve from 0.02187
# Epoch 8/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0066 - mse: 0.0131 - val_loss: 0.0407 - val_mse: 0.0813
#
# Epoch 00008: val_loss did not improve from 0.02187
# Epoch 9/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0067 - mse: 0.0135 - val_loss: 0.0415 - val_mse: 0.0830
#
# Epoch 00009: val_loss did not improve from 0.02187
# Epoch 10/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0069 - mse: 0.0138 - val_loss: 0.0418 - val_mse: 0.0836
#
# Epoch 00010: val_loss did not improve from 0.02187
# Epoch 11/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0064 - mse: 0.0128 - val_loss: 0.0410 - val_mse: 0.0820
#
# Epoch 00011: val_loss did not improve from 0.02187
# Epoch 1/50
# 239/239 [==============================] - 3s 6ms/step - loss: 0.0072 - mse: 0.0144 - val_loss: 0.0495 - val_mse: 0.0990
#
# Epoch 00001: val_loss improved from inf to 0.04949, saving model to tmp\Brokerageckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0083 - mse: 0.0165 - val_loss: 0.0438 - val_mse: 0.0876
#
# Epoch 00002: val_loss improved from 0.04949 to 0.04379, saving model to tmp\Brokerageckeckpointer.ckpt
# Epoch 3/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0081 - mse: 0.0162 - val_loss: 0.0380 - val_mse: 0.0760
#
# Epoch 00003: val_loss improved from 0.04379 to 0.03800, saving model to tmp\Brokerageckeckpointer.ckpt
# Epoch 4/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0079 - mse: 0.0158 - val_loss: 0.0384 - val_mse: 0.0768
#
# Epoch 00004: val_loss did not improve from 0.03800
# Epoch 5/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0081 - mse: 0.0162 - val_loss: 0.0346 - val_mse: 0.0692
#
# Epoch 00005: val_loss improved from 0.03800 to 0.03461, saving model to tmp\Brokerageckeckpointer.ckpt
# Epoch 6/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0076 - mse: 0.0151 - val_loss: 0.0482 - val_mse: 0.0964
#
# Epoch 00006: val_loss did not improve from 0.03461
# Epoch 7/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0083 - mse: 0.0165 - val_loss: 0.0356 - val_mse: 0.0713
#
# Epoch 00007: val_loss did not improve from 0.03461
# Epoch 8/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0077 - mse: 0.0154 - val_loss: 0.0367 - val_mse: 0.0734
#
# Epoch 00008: val_loss did not improve from 0.03461
# Epoch 9/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0081 - mse: 0.0162 - val_loss: 0.0336 - val_mse: 0.0672
#
# Epoch 00009: val_loss improved from 0.03461 to 0.03360, saving model to tmp\Brokerageckeckpointer.ckpt
# Epoch 10/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0069 - mse: 0.0139 - val_loss: 0.0502 - val_mse: 0.1005
#
# Epoch 00010: val_loss did not improve from 0.03360
# Epoch 11/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0083 - mse: 0.0165 - val_loss: 0.0365 - val_mse: 0.0730
#
# Epoch 00011: val_loss did not improve from 0.03360
# Epoch 12/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0081 - mse: 0.0163 - val_loss: 0.0351 - val_mse: 0.0701
#
# Epoch 00012: val_loss did not improve from 0.03360
# Epoch 13/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0079 - mse: 0.0157 - val_loss: 0.0347 - val_mse: 0.0694
#
# Epoch 00013: val_loss did not improve from 0.03360
# Epoch 14/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0082 - mse: 0.0164 - val_loss: 0.0337 - val_mse: 0.0674
#
# Epoch 00014: val_loss did not improve from 0.03360
# Epoch 15/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0082 - mse: 0.0164 - val_loss: 0.0346 - val_mse: 0.0693
#
# Epoch 00015: val_loss did not improve from 0.03360
# Epoch 16/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0082 - mse: 0.0163 - val_loss: 0.0349 - val_mse: 0.0697
#
# Epoch 00016: val_loss did not improve from 0.03360
# Epoch 17/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0083 - mse: 0.0166 - val_loss: 0.0339 - val_mse: 0.0679
#
# Epoch 00017: val_loss did not improve from 0.03360
# Epoch 18/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0083 - mse: 0.0166 - val_loss: 0.0353 - val_mse: 0.0707
#
# Epoch 00018: val_loss did not improve from 0.03360
# Epoch 19/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0083 - mse: 0.0166 - val_loss: 0.0359 - val_mse: 0.0718
#
# Epoch 00019: val_loss did not improve from 0.03360
# Epoch 1/50
# 239/239 [==============================] - 3s 6ms/step - loss: 0.0041 - mse: 0.0082 - val_loss: 0.0103 - val_mse: 0.0206
#
# Epoch 00001: val_loss improved from inf to 0.01029, saving model to tmp\Insurerckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0034 - mse: 0.0069 - val_loss: 0.0103 - val_mse: 0.0206
#
# Epoch 00002: val_loss improved from 0.01029 to 0.01028, saving model to tmp\Insurerckeckpointer.ckpt
# Epoch 3/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0034 - mse: 0.0068 - val_loss: 0.0097 - val_mse: 0.0195
#
# Epoch 00003: val_loss improved from 0.01028 to 0.00973, saving model to tmp\Insurerckeckpointer.ckpt
# Epoch 4/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0034 - mse: 0.0068 - val_loss: 0.0113 - val_mse: 0.0226
#
# Epoch 00004: val_loss did not improve from 0.00973
# Epoch 5/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0034 - mse: 0.0069 - val_loss: 0.0123 - val_mse: 0.0247
#
# Epoch 00005: val_loss did not improve from 0.00973
# Epoch 6/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0033 - mse: 0.0066 - val_loss: 0.0111 - val_mse: 0.0223
#
# Epoch 00006: val_loss did not improve from 0.00973
# Epoch 7/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0032 - mse: 0.0064 - val_loss: 0.0101 - val_mse: 0.0202
#
# Epoch 00007: val_loss did not improve from 0.00973
# Epoch 8/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0034 - mse: 0.0068 - val_loss: 0.0123 - val_mse: 0.0245
#
# Epoch 00008: val_loss did not improve from 0.00973
# Epoch 9/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0033 - mse: 0.0066 - val_loss: 0.0117 - val_mse: 0.0235
#
# Epoch 00009: val_loss did not improve from 0.00973
# Epoch 10/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0037 - mse: 0.0073 - val_loss: 0.0134 - val_mse: 0.0269
#
# Epoch 00010: val_loss did not improve from 0.00973
# Epoch 11/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0039 - mse: 0.0078 - val_loss: 0.0152 - val_mse: 0.0304
#
# Epoch 00011: val_loss did not improve from 0.00973
# Epoch 12/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mse: 0.0083 - val_loss: 0.0169 - val_mse: 0.0338
#
# Epoch 00012: val_loss did not improve from 0.00973
# Epoch 13/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0039 - mse: 0.0078 - val_loss: 0.0110 - val_mse: 0.0221
#
# Epoch 00013: val_loss did not improve from 0.00973
# Epoch 1/50
# 239/239 [==============================] - 3s 6ms/step - loss: 0.0012 - mse: 0.0024 - val_loss: 0.0486 - val_mse: 0.0972
#
# Epoch 00001: val_loss improved from inf to 0.04858, saving model to tmp\Serviceckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0046 - mse: 0.0092 - val_loss: 0.0471 - val_mse: 0.0943
#
# Epoch 00002: val_loss improved from 0.04858 to 0.04713, saving model to tmp\Serviceckeckpointer.ckpt
# Epoch 3/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0054 - mse: 0.0107 - val_loss: 0.0525 - val_mse: 0.1050
#
# Epoch 00003: val_loss did not improve from 0.04713
# Epoch 4/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0066 - mse: 0.0131 - val_loss: 0.0674 - val_mse: 0.1348
#
# Epoch 00004: val_loss did not improve from 0.04713
# Epoch 5/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0072 - mse: 0.0145 - val_loss: 0.0740 - val_mse: 0.1480
#
# Epoch 00005: val_loss did not improve from 0.04713
# Epoch 6/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0050 - mse: 0.0100 - val_loss: 0.0461 - val_mse: 0.0923
#
# Epoch 00006: val_loss improved from 0.04713 to 0.04614, saving model to tmp\Serviceckeckpointer.ckpt
# Epoch 7/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0065 - mse: 0.0131 - val_loss: 0.0775 - val_mse: 0.1550
#
# Epoch 00007: val_loss did not improve from 0.04614
# Epoch 8/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0054 - mse: 0.0107 - val_loss: 0.0461 - val_mse: 0.0922
#
# Epoch 00008: val_loss improved from 0.04614 to 0.04608, saving model to tmp\Serviceckeckpointer.ckpt
# Epoch 9/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0058 - mse: 0.0116 - val_loss: 0.0655 - val_mse: 0.1310
#
# Epoch 00009: val_loss did not improve from 0.04608
# Epoch 10/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0065 - mse: 0.0130 - val_loss: 0.0732 - val_mse: 0.1464
#
# Epoch 00010: val_loss did not improve from 0.04608
# Epoch 11/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0050 - mse: 0.0101 - val_loss: 0.0504 - val_mse: 0.1008
#
# Epoch 00011: val_loss did not improve from 0.04608
# Epoch 12/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0064 - mse: 0.0129 - val_loss: 0.0596 - val_mse: 0.1191
#
# Epoch 00012: val_loss did not improve from 0.04608
# Epoch 13/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0051 - mse: 0.0102 - val_loss: 0.0519 - val_mse: 0.1039
#
# Epoch 00013: val_loss did not improve from 0.04608
# Epoch 14/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0060 - mse: 0.0120 - val_loss: 0.0510 - val_mse: 0.1020
#
# Epoch 00014: val_loss did not improve from 0.04608
# Epoch 15/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0073 - mse: 0.0146 - val_loss: 0.0731 - val_mse: 0.1461
#
# Epoch 00015: val_loss did not improve from 0.04608
# Epoch 16/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0075 - mse: 0.0150 - val_loss: 0.0837 - val_mse: 0.1675
#
# Epoch 00016: val_loss did not improve from 0.04608
# Epoch 17/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0078 - mse: 0.0156 - val_loss: 0.0815 - val_mse: 0.1631
#
# Epoch 00017: val_loss did not improve from 0.04608
# Epoch 18/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0069 - mse: 0.0139 - val_loss: 0.0479 - val_mse: 0.0958
#
# Epoch 00018: val_loss did not improve from 0.04608
# Epoch 1/50
# 239/239 [==============================] - 3s 6ms/step - loss: 0.0050 - mse: 0.0101 - val_loss: 0.0362 - val_mse: 0.0724
#
# Epoch 00001: val_loss improved from inf to 0.03620, saving model to tmp\Manufacturerckeckpointer.ckpt
# Epoch 2/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0036 - mse: 0.0072 - val_loss: 0.0398 - val_mse: 0.0797
#
# Epoch 00002: val_loss did not improve from 0.03620
# Epoch 3/50
# 239/239 [==============================] - 1s 5ms/step - loss: 0.0035 - mse: 0.0071 - val_loss: 0.0341 - val_mse: 0.0683
#
# Epoch 00003: val_loss improved from 0.03620 to 0.03414, saving model to tmp\Manufacturerckeckpointer.ckpt
# Epoch 4/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0036 - mse: 0.0072 - val_loss: 0.0397 - val_mse: 0.0794
#
# Epoch 00004: val_loss did not improve from 0.03414
# Epoch 5/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0038 - mse: 0.0076 - val_loss: 0.0401 - val_mse: 0.0802
#
# Epoch 00005: val_loss did not improve from 0.03414
# Epoch 6/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0041 - mse: 0.0083 - val_loss: 0.0395 - val_mse: 0.0790
#
# Epoch 00006: val_loss did not improve from 0.03414
# Epoch 7/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0044 - mse: 0.0088 - val_loss: 0.0388 - val_mse: 0.0775
#
# Epoch 00007: val_loss did not improve from 0.03414
# Epoch 8/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0046 - mse: 0.0093 - val_loss: 0.0386 - val_mse: 0.0773
#
# Epoch 00008: val_loss did not improve from 0.03414
# Epoch 9/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0048 - mse: 0.0096 - val_loss: 0.0374 - val_mse: 0.0749
#
# Epoch 00009: val_loss did not improve from 0.03414
# Epoch 10/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0051 - mse: 0.0103 - val_loss: 0.0372 - val_mse: 0.0744
#
# Epoch 00010: val_loss did not improve from 0.03414
# Epoch 11/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0052 - mse: 0.0105 - val_loss: 0.0378 - val_mse: 0.0756
#
# Epoch 00011: val_loss did not improve from 0.03414
# Epoch 12/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0051 - mse: 0.0103 - val_loss: 0.0375 - val_mse: 0.0750
#
# Epoch 00012: val_loss did not improve from 0.03414
# Epoch 13/50
# 239/239 [==============================] - 1s 4ms/step - loss: 0.0053 - mse: 0.0107 - val_loss: 0.0372 - val_mse: 0.0743
#
# Epoch 00013: val_loss did not improve from 0.03414

# %%
load_model_checkpoint={}
for sector_name, sector_model in filename_dic.items():
    load_model_checkpoint[sector_name] = model_dic[sector_name].load_weights(filename_dic[sector_name])

# %% [markdown]
# # 예측 데이터 시각화
# 아래 시각화 코드중 y_test 데이터에 [20:]으로 슬라이싱을 한 이유는
#
# 예측 데이터에서 20일치의 데이터로 21일치를 예측해야하기 때문에 test_data로 예측 시 앞의 20일은 예측하지 않습니다.
#
# 따라서, 20번 째 index와 비교하면 더욱 정확합니다.

# %%
for sector_name, model in model_dic.items():
    pred = model.predict(tf_dataset_test_dic[sector_name])
    print(f'{sector_name}의 test_data의 출력 크기 : ' ,pred.shape)
    plt.figure(figsize=(12, 9))
    plt.plot(np.asarray(y_test_dic[sector_name])[20::10], label='actual')
    plt.plot(pred, label='prediction')
    #plt.xticks(test_dic[sector_name].index)
    plt.legend()
    plt.show()
# Out:
# Food의 test_data의 출력 크기 :  (59, 1)
# Clothing의 test_data의 출력 크기 :  (59, 1)
# Chemical의 test_data의 출력 크기 :  (59, 1)
# Medicine의 test_data의 출력 크기 :  (59, 1)
# Non_Metal의 test_data의 출력 크기 :  (59, 1)
# Metal의 test_data의 출력 크기 :  (59, 1)
# Machine의 test_data의 출력 크기 :  (59, 1)
# Electronic의 test_data의 출력 크기 :  (59, 1)
# Construction의 test_data의 출력 크기 :  (59, 1)
# Transport의 test_data의 출력 크기 :  (59, 1)
# Distribution의 test_data의 출력 크기 :  (59, 1)
# Power의 test_data의 출력 크기 :  (59, 1)
# Tele의 test_data의 출력 크기 :  (59, 1)
# Finance의 test_data의 출력 크기 :  (59, 1)
# Brokerage의 test_data의 출력 크기 :  (59, 1)
# Insurer의 test_data의 출력 크기 :  (59, 1)
# Service의 test_data의 출력 크기 :  (59, 1)
# Manufacturer의 test_data의 출력 크기 :  (59, 1)

# %%
X_test_dic['Food'].shape
# Out:
# (600, 3)
